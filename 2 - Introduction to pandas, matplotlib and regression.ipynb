# %%
import numpy

# things we already know
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor


# things we learn today
import pandas

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.svm import SVC, SVR

# %% [markdown]
# ## Plotting in IPython
#
# below we use a **magic function**. It is a term!
#
# It says: activate matplotlib, show plots inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = numpy.array([-3, -2, -1, 0, 1, 2, 3, 4])
print x
print x ** 2

plt.plot(x, x ** 2)
# Out:
# [-3 -2 -1  0  1  2  3  4]
# [ 9  4  1  0  1  4  9 16]

# %%
distribution = numpy.random.normal(loc=1., scale=2, size=10000)
plt.hist(distribution)
pass

# %%
plt.hist(numpy.random.normal(loc=5., scale=2, size=10000), bins=30, alpha=0.4, normed=True, label='first')
plt.hist(numpy.random.normal(loc=7., scale=3, size=10000), bins=30, alpha=0.4, normed=True, label='second')
plt.hist(numpy.random.normal(loc=0., scale=1, size=10000), bins=30, alpha=0.4, normed=True, label='third')
plt.legend()
pass

# %%
# Large scatter plot
plt.figure(figsize=[12, 10])
plt.scatter(numpy.random.normal(size=300), numpy.random.normal(size=300))

# %% [markdown]
# ## Magics
#
# magics are not needed so far, those are just for the information

# %%
# sample two arrays of random numbers sampled from unifrom [0, 1]
a = numpy.random.random(size=1000000)
b = numpy.random.random(size=1000000)
# measure time needed for operation
# %time result = a + b
# Out:
# Wall time: 4 ms

# %%
# %%time
# measure the time needed to run whole cell (%%, not %)
a = numpy.random.random(size=1000000)
b = numpy.random.random(size=1000000)
result = a + b
# Out:
# Wall time: 54 ms

# %%
# profiling of complex code
# %prun numpy.histogram(x)

# %%
# general info about magics in IPython
# %magic

# %% [markdown]
# following code works on my computer, since I have ruby installed

# %%
# %%ruby
# def greet
#    puts 'Hello from Ruby!'
# end
# greet()
# Out:
# Couldn't find program: u'ruby'

# %% [markdown]
# # Pandas
#
# Downloading dataset

# %%
# !head data/2-winequality-white.csv
# Out:
# "fixed acidity";"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4;9.9;6
# 8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;10.1;6
# 6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;9.6;6
# 7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9.5;6

# %%
data = pandas.read_csv('data/2-winequality-white.csv', sep=';')
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   45                   170   1.0010  3.00       0.45
# 1                   14                   132   0.9940  3.30       0.49
# 2                   30                    97   0.9951  3.26       0.44
# 3                   47                   186   0.9956  3.19       0.40
# 4                   47                   186   0.9956  3.19       0.40
# 5                   30                    97   0.9951  3.26       0.44
# 6                   30                   136   0.9949  3.18       0.47
# 7                   45                   170   1.0010  3.00       0.45
# 8                   14                   132   0.9940  3.30       0.49
# 9                   28                   129   0.9938  3.22       0.45
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# 5     10.1        6
# 6      9.6        6
# 7      8.8        6
# 8      9.5        6
# 9     11.0        6

# %%
y = data['quality']
X = data.drop('quality', axis=1)

# %%
X.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   45                   170   1.0010  3.00       0.45
# 1                   14                   132   0.9940  3.30       0.49
# 2                   30                    97   0.9951  3.26       0.44
# 3                   47                   186   0.9956  3.19       0.40
# 4                   47                   186   0.9956  3.19       0.40
# 5                   30                    97   0.9951  3.26       0.44
# 6                   30                   136   0.9949  3.18       0.47
# 7                   45                   170   1.0010  3.00       0.45
# 8                   14                   132   0.9940  3.30       0.49
# 9                   28                   129   0.9938  3.22       0.45
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9
# 5     10.1
# 6      9.6
# 7      8.8
# 8      9.5
# 9     11.0

# %% [markdown]
# ## Operations with pandas

# %%
#leaving only 14 rows for testing
test_frame = data[:14].copy()

# %%
test_frame
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 13            6.6              0.16         0.40            1.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45                   170   1.0010  3.00       0.45
# 1                    14                   132   0.9940  3.30       0.49
# 2                    30                    97   0.9951  3.26       0.44
# 3                    47                   186   0.9956  3.19       0.40
# 4                    47                   186   0.9956  3.19       0.40
# 5                    30                    97   0.9951  3.26       0.44
# 6                    30                   136   0.9949  3.18       0.47
# 7                    45                   170   1.0010  3.00       0.45
# 8                    14                   132   0.9940  3.30       0.49
# 9                    28                   129   0.9938  3.22       0.45
# 10                   11                    63   0.9908  2.99       0.56
# 11                   17                   109   0.9947  3.14       0.53
# 12                   16                    75   0.9920  3.18       0.63
# 13                   48                   143   0.9912  3.54       0.52
#
#     alcohol  quality
# 0       8.8        6
# 1       9.5        6
# 2      10.1        6
# 3       9.9        6
# 4       9.9        6
# 5      10.1        6
# 6       9.6        6
# 7       8.8        6
# 8       9.5        6
# 9      11.0        6
# 10     12.0        5
# 11      9.7        5
# 12     10.8        5
# 13     12.4        7

# %%
test_frame['density']
# Out:
# 0     1.0010
# 1     0.9940
# 2     0.9951
# 3     0.9956
# 4     0.9956
# 5     0.9951
# 6     0.9949
# 7     1.0010
# 8     0.9940
# 9     0.9938
# 10    0.9908
# 11    0.9947
# 12    0.9920
# 13    0.9912
# Name: density, dtype: float64

# %%
# converting to numpy.array
test_frame['density'].values
# Out:
# array([ 1.001 ,  0.994 ,  0.9951,  0.9956,  0.9956,  0.9951,  0.9949,
#         1.001 ,  0.994 ,  0.9938,  0.9908,  0.9947,  0.992 ,  0.9912])

# %%
test_frame['fixed acidity'][:5]
# Out:
# 0    7.0
# 1    6.3
# 2    8.1
# 3    7.2
# 4    7.2
# Name: fixed acidity, dtype: float64

# %%
# indexing with numbers - iloc
test_frame.iloc[[0, 4, 7], 2:7]
# Out:
#    citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0         0.36            20.7      0.045                   45
# 4         0.32             8.5      0.058                   47
# 7         0.36            20.7      0.045                   45
#
#    total sulfur dioxide
# 0                   170
# 4                   186
# 7                   170

# %%
# indexing with named labels - loc
test_frame.loc[:, ['volatile acidity', 'fixed acidity']]
# Out:
#     volatile acidity  fixed acidity
# 0               0.27            7.0
# 1               0.30            6.3
# 2               0.28            8.1
# 3               0.23            7.2
# 4               0.23            7.2
# 5               0.28            8.1
# 6               0.32            6.2
# 7               0.27            7.0
# 8               0.30            6.3
# 9               0.22            8.1
# 10              0.27            8.1
# 11              0.23            8.6
# 12              0.18            7.9
# 13              0.16            6.6

# %%
# shortcut for previous
test_frame[['volatile acidity', 'fixed acidity']]
# Out:
#     volatile acidity  fixed acidity
# 0               0.27            7.0
# 1               0.30            6.3
# 2               0.28            8.1
# 3               0.23            7.2
# 4               0.23            7.2
# 5               0.28            8.1
# 6               0.32            6.2
# 7               0.27            7.0
# 8               0.30            6.3
# 9               0.22            8.1
# 10              0.27            8.1
# 11              0.23            8.6
# 12              0.18            7.9
# 13              0.16            6.6

# %%
test_frame.iloc[::3, ::-1]
# Out:
#     quality  alcohol  sulphates    pH  density  total sulfur dioxide  \
# 0         6      8.8       0.45  3.00   1.0010                   170
# 3         6      9.9       0.40  3.19   0.9956                   186
# 6         6      9.6       0.47  3.18   0.9949                   136
# 9         6     11.0       0.45  3.22   0.9938                   129
# 12        5     10.8       0.63  3.18   0.9920                    75
#
#     free sulfur dioxide  chlorides  residual sugar  citric acid  \
# 0                    45      0.045            20.7         0.36
# 3                    47      0.058             8.5         0.32
# 6                    30      0.045             7.0         0.16
# 9                    28      0.044             1.5         0.43
# 12                   16      0.040             1.2         0.37
#
#     volatile acidity  fixed acidity
# 0               0.27            7.0
# 3               0.23            7.2
# 6               0.32            6.2
# 9               0.22            8.1
# 12              0.18            7.9

# %%
# adding new feature
test_frame['dioxide sum'] = test_frame['total sulfur dioxide'] + test_frame['free sulfur dioxide']
test_frame
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.0              0.27         0.36           20.70      0.045
# 1             6.3              0.30         0.34            1.60      0.049
# 2             8.1              0.28         0.40            6.90      0.050
# 3             7.2              0.23         0.32            8.50      0.058
# 4             7.2              0.23         0.32            8.50      0.058
# 5             8.1              0.28         0.40            6.90      0.050
# 6             6.2              0.32         0.16            7.00      0.045
# 7             7.0              0.27         0.36           20.70      0.045
# 8             6.3              0.30         0.34            1.60      0.049
# 9             8.1              0.22         0.43            1.50      0.044
# 10            8.1              0.27         0.41            1.45      0.033
# 11            8.6              0.23         0.40            4.20      0.035
# 12            7.9              0.18         0.37            1.20      0.040
# 13            6.6              0.16         0.40            1.50      0.044
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45                   170   1.0010  3.00       0.45
# 1                    14                   132   0.9940  3.30       0.49
# 2                    30                    97   0.9951  3.26       0.44
# 3                    47                   186   0.9956  3.19       0.40
# 4                    47                   186   0.9956  3.19       0.40
# 5                    30                    97   0.9951  3.26       0.44
# 6                    30                   136   0.9949  3.18       0.47
# 7                    45                   170   1.0010  3.00       0.45
# 8                    14                   132   0.9940  3.30       0.49
# 9                    28                   129   0.9938  3.22       0.45
# 10                   11                    63   0.9908  2.99       0.56
# 11                   17                   109   0.9947  3.14       0.53
# 12                   16                    75   0.9920  3.18       0.63
# 13                   48                   143   0.9912  3.54       0.52
#
#     alcohol  quality  dioxide sum
# 0       8.8        6          215
# 1       9.5        6          146
# 2      10.1        6          127
# 3       9.9        6          233
# 4       9.9        6          233
# 5      10.1        6          127
# 6       9.6        6          166
# 7       8.8        6          215
# 8       9.5        6          146
# 9      11.0        6          157
# 10     12.0        5           74
# 11      9.7        5          126
# 12     10.8        5           91
# 13     12.4        7          191

# %%
filtered_data = data[data['density'] < 0.988]
filtered_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2945            4.9             0.330         0.31             1.2      0.016
# 3367            6.0             0.290         0.25             1.4      0.033
# 3370            6.0             0.290         0.25             1.4      0.033
# 3673            5.4             0.300         0.30             1.2      0.029
# 3676            5.3             0.300         0.30             1.2      0.029
# 3710            4.7             0.670         0.09             1.0      0.020
# 3773            5.0             0.610         0.12             1.3      0.009
# 3904            5.0             0.455         0.18             1.9      0.036
# 3915            4.7             0.455         0.18             1.9      0.036
# 3918            6.4             0.350         0.28             1.6      0.037
# 4149            5.8             0.240         0.28             1.4      0.038
# 4645            5.0             0.240         0.34             1.1      0.034
# 4789            5.5             0.620         0.33             1.7      0.037
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2945                   39                   150  0.98713  3.33       0.59
# 3367                   30                   114  0.98794  3.08       0.43
# 3370                   30                   114  0.98794  3.08       0.43
# 3673                   25                    93  0.98742  3.31       0.40
# 3676                   25                    93  0.98742  3.31       0.40
# 3710                    5                     9  0.98722  3.30       0.34
# 3773                   65                   100  0.98740  3.26       0.37
# 3904                   33                   106  0.98746  3.21       0.83
# 3915                   33                   106  0.98746  3.21       0.83
# 3918                   31                   113  0.98779  3.12       0.40
# 4149                   40                    76  0.98711  3.10       0.29
# 4645                   49                   158  0.98774  3.32       0.32
# 4789                   24                   118  0.98758  3.15       0.39
#
#       alcohol  quality
# 2945    14.00        8
# 3367    13.20        6
# 3370    13.20        6
# 3673    13.60        7
# 3676    13.60        7
# 3710    13.60        5
# 3773    13.50        5
# 3904    14.00        7
# 3915    14.00        7
# 3918    14.20        7
# 4149    13.90        7
# 4645    13.10        7
# 4789    13.55        6

# %%
print len(test_frame), test_frame.shape 
print test_frame.columns
print len(X.columns)
# Out:
# 14 (14, 13)
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality', u'dioxide sum'],
#       dtype='object')
# 11

# %%
plt.scatter(X['total sulfur dioxide'], X['volatile acidity'], c=y, alpha=0.4)
plt.colorbar()

# %% [markdown]
# ## Exercise
# 1. plot histograms of all features in dataset
# 2. Let's classify wines in:
#    * good means quality >= 7
#    * bad means quality <= 4
#    * mediocre means quality five or six
#
#    Plot histograms of all features for good and bad wines. Which feature is most discriminative?
#
# 3. Plot some scatter plots:
#    - alcohol vs fixed acidity for good and bad wines, what can we say about good wines?
#    - alcohol vs fixed acidity for quality=5 and quality=6
#    - alcohol vs density for good and bad wines. What can we conclude?

# %%
## Exercise 1
for i in range(0, len(data.columns)):
    plt.figure(i)
    plt.hist(data.iloc[::,i], normed=False, bins=30, label = (test_frame.columns[i]))
    pass
    plt.legend()

# %%
##Exercise 2
data_clf=data.copy()
data_clf['classification'] = ""

# %%
data_clf['classification'][data_clf['quality']>=7] = "Good"
data_clf['classification'][data_clf['quality']<=4] = "Bad"
data_clf['classification'][data_clf['quality']==5] = "Mediocre"
data_clf['classification'][data_clf['quality']==6] = "Mediocre"
# Out:
# C:\Users\Yanjie\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Yanjie\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Yanjie\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Yanjie\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_g=data_clf[(data_clf['classification']=="Good")].copy()
data_b=data_clf[(data_clf['classification']=="Bad")].copy()

# %%
data_g_plt=data_g.reset_index(drop=True)
data_b_plt=data_b.reset_index(drop=True)

# %%
for i in range(1, len(data_g_plt.columns)-1):
    plt.figure(i)
    plt.hist(data_g_plt.iloc[::,i], normed=True, bins=30, alpha = 0.4, label = 'Good')
    plt.hist(data_b_plt.iloc[::,i], normed=True, bins=30, alpha = 0.4, label = 'Bad')
    plt.title(data_g_plt.columns[i])
    pass
    plt.legend()

# %%
score_g =

# %%
##Exercise 3

plt.scatter(data_g['alcohol'], data_g['fixed acidity'], c = 'blue', label = 'Good', alpha=0.4)
plt.scatter(data_b['alcohol'], data_b['fixed acidity'], c = 'red', label = 'Bad', alpha=0.4)
plt.xlabel('alcohol')
plt.ylabel('fixed acidity')
#plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data_m=data_clf[(data_clf['classification']=="Mediocre")].copy()
data_m_plt=data_m.reset_index(drop=True)

plt.scatter(data_g['alcohol'], data_g['fixed acidity'], c = 'blue', label = 'Good', alpha=0.4)
plt.scatter(data_b['alcohol'], data_b['fixed acidity'], c = 'red', label = 'Bad', alpha=0.4)
plt.scatter(data_m['alcohol'], data_m['fixed acidity'], c = 'yellow', label = 'Mediocre', alpha=0.4)
plt.xlabel('alcohol')
plt.ylabel('fixed acidity')
#plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(data_g['alcohol'], data_g['density'], c = 'blue', label = 'Good', alpha=0.4)
plt.scatter(data_b['alcohol'], data_b['density'], c = 'red', label = 'Bad', alpha=0.4)
plt.xlabel('alcohol')
plt.ylabel('fdensity')
#plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
##Linear relationship between alcohol and fdensity

# %% [markdown]
# ## Linear models

# %%
trainX, testX, trainY, testY = train_test_split(X, y, random_state=42)

# %%
for alpha in [0., 0.001, 0.01, 0.1, 1, 10, 100]:
    linear_reg = Ridge(alpha)
    linear_reg.fit(trainX, trainY)
    print alpha, '\t', mean_squared_error(testY, linear_reg.predict(testX))
# Out:
# 0.0 	0.564587791519
# 0.001 	0.568293991144
# 0.01 	0.573570550784
# 0.1 	0.574990791682
# 1 	0.575287625141
# 10 	0.576469007479
# 100 	0.593064358623

# %% [markdown]
# ## Linear models with non linear features

# %%
numpy.tanh(1.732)
# Out:
# 0.93929183800868699

# %%
from sklearn.preprocessing import StandardScaler

X_extend = StandardScaler().fit_transform(X)
print X_extend
X_extend = pandas.DataFrame(X_extend, columns=X.columns)
print X_extend

for f in X_extend.columns:
    X_extend[f + '_abs']  = numpy.abs(X_extend[f])
    X_extend[f + '_tanh'] = numpy.tanh(X_extend[f])
print X_extend
# Out:
# [[  1.72096961e-01  -8.17699008e-02   2.13280202e-01 ...,  -1.24692128e+00
#    -3.49184257e-01  -1.39315246e+00]
#  [ -6.57501128e-01   2.15895632e-01   4.80011213e-02 ...,   7.40028640e-01
#     1.34184656e-03  -8.24275678e-01]
#  [  1.47575110e+00   1.74519434e-02   5.43838363e-01 ...,   4.75101984e-01
#    -4.36815783e-01  -3.36667007e-01]
#  ...,
#  [ -4.20473102e-01  -3.79435433e-01  -1.19159198e+00 ...,  -1.31315295e+00
#    -2.61552731e-01  -9.05543789e-01]
#  [ -1.60561323e+00   1.16673788e-01  -2.82557040e-01 ...,   1.00495530e+00
#    -9.62604939e-01   1.85757201e+00]
#  [ -1.01304317e+00  -6.77100966e-01   3.78559282e-01 ...,   4.75101984e-01
#    -1.48839409e+00   1.04489089e+00]]
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1         -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2          1.475751          0.017452     0.543838        0.100282   0.193523
# 3          0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4          0.409125         -0.478657    -0.117278        0.415768   0.559727
# 5          1.475751          0.017452     0.543838        0.100282   0.193523
# 6         -0.776015          0.414339    -1.439511        0.120000  -0.035355
# 7          0.172097         -0.081770     0.213280        2.821349  -0.035355
# 8         -0.657501          0.215896     0.048001       -0.944765   0.147747
# 9          1.475751         -0.577879     0.791757       -0.964483  -0.081131
# 10         1.475751         -0.081770     0.626478       -0.974342  -0.584661
# 11         2.068321         -0.478657     0.543838       -0.432100  -0.493110
# 12         1.238723         -0.974766     0.295920       -1.023637  -0.264233
# 13        -0.301959         -1.173210     0.543838       -0.964483  -0.081131
# 14         1.712779          1.406558     2.361908        2.535440  -0.264233
# 15        -0.301959         -1.073988     0.378559       -0.964483  -0.630437
# 16        -0.657501          2.001889    -2.431185       -1.043355   0.010421
# 17        -0.776015          3.787882     1.204955       -1.023637  -0.767763
# 18         0.646153          0.612783     0.709117       -1.043355  -0.584661
# 19        -0.420473          0.315117    -1.604790        0.218589  -0.081131
# 20        -0.776015          3.787882     1.204955       -1.023637  -0.767763
# 21        -0.538987          0.315117     0.378559       -0.688433  -0.355784
# 22        -0.064931         -0.180992     0.709117       -0.925047   0.147747
# 23         0.883181          3.887104    -1.604790       -0.964483   1.292135
# 24        -0.301959         -0.081770     0.626478       -1.003919   0.285074
# 25         0.172097         -0.280214    -0.117278        0.514358   0.010421
# 26         0.053583         -0.379435     0.130641       -1.063073   0.285074
# 27         0.172097          0.017452     0.461199        0.455204   0.239298
# 28         0.646153         -0.081770     1.204955       -1.043355   0.056196
# 29         0.409125          0.414339     0.213280       -0.865894  -0.584661
# 20              -0.370946             -1.491059 -1.614182  0.938724
# 21              -0.958994             -0.855671 -0.945421 -0.120983
# 22               0.334712             -0.385013 -0.343535  1.865967
# 23              -0.606165              0.697499 -0.109468 -0.915763
# 24              -1.135409              0.085644  0.358665  1.534809
# 25               1.216785              2.509531  0.492417  0.408870
# 26              -0.018117              0.179776 -0.343535  1.733504
# 27              -0.194531              0.062111  0.693046  1.269882
# 28              -1.076604             -0.149685 -0.878544  0.011480
# 29               0.099493             -0.573277 -1.146049 -0.584605
# ...                   ...                   ...       ...       ...
# 4868             0.393517             -0.337948 -0.263284  0.806260
# 4869            -1.605848             -1.349862  0.746547  0.011480
# 4870            -0.370946             -0.149685 -0.718042 -0.253446
# 4871            -0.900190             -0.949803 -1.446992  1.203650
# 4872             0.863956              0.956361  0.733171 -0.319678
# 4873            -0.135727             -0.385013 -1.199550  0.938724
# 4874            -1.135409             -0.314415 -0.403724  1.998430
# 4875            -1.017799             -0.973336 -0.527445 -0.452141
# 4876            -0.076922             -0.502678 -0.905295  1.137419
# 4877            -1.370628             -1.326329 -0.390348  0.408870
# 4878            -1.723457             -1.349862 -0.564226  0.342639
# 4879             1.922443              0.744565  0.305164 -0.253446
# 4880             1.922443              0.744565  0.305164 -0.253446
# 4881            -0.076922             -0.479145  0.458979 -0.783300
# 4882             0.569932              0.415105 -0.731417  0.475102
# 4883             1.452004              0.226842 -1.467055  0.541334
# 4884             1.922443              0.838697  0.298476 -0.319678
# 4885             1.922443              0.744565  0.305164 -0.253446
# 4886             0.569932             -0.408546 -0.784918  0.143944
# 4887            -1.782262             -1.938184 -1.587432 -0.981995
# 4888             0.158298             -0.267349 -0.243221 -0.981995
# 4889            -0.076922             -0.479145  0.458979 -0.783300
# 4890            -0.606165             -0.902737 -1.553994 -0.849531
# 4891             0.158298             -0.408546 -1.099236  0.342639
# 4892            -0.370946             -0.620342 -0.350223  0.673797
# 4893            -0.664970             -1.091000 -0.965483  0.541334
# 4894             1.275590              0.697499  0.291789 -0.253446
# 4895            -0.312141             -0.643875 -0.497350 -1.313153
# 4896            -0.900190             -0.667408 -1.784717  1.004955
# 4897            -0.782580             -0.949803 -1.543962  0.475102
#
#       sulphates      ...       total sulfur dioxide_abs  \
# 0     -0.349184      ...                       0.744565
# 1      0.001342      ...                       0.149685
# 2     -0.436816      ...                       0.973336
# 3     -0.787342      ...                       1.121091
# 4     -0.787342      ...                       1.121091
# 5     -0.436816      ...                       0.973336
# 6     -0.173921      ...                       0.055553
# 7     -0.349184      ...                       0.744565
# 8      0.001342      ...                       0.149685
# 9     -0.349184      ...                       0.220283
# 10     0.614763      ...                       1.773454
# 11     0.351868      ...                       0.690941
# 12     1.228183      ...                       1.491059
# 13     0.264236      ...                       0.109177
# 14     1.578709      ...                       0.791631
# 15     0.527131      ...                       0.620342
# 16    -1.137868      ...                       0.926270
# 17    -0.874973      ...                       1.491059
# 18     0.351868      ...                       0.768098
# 19     0.088973      ...                       0.126152
# 20    -0.874973      ...                       1.491059
# 21    -1.225500      ...                       0.855671
# 20    0.734635       0.874973       -0.703892     1.857572      0.952454
# 21   -0.120396       1.225500       -0.841269     0.394746      0.375444
# 22    0.953227       0.086290       -0.086076     0.011595     -0.011594
# 23   -0.723887       0.176605        0.174791     0.986812     -0.756000
# 24    0.911244       0.173921       -0.172189     0.417935     -0.395189
# 25    0.387513       0.088973        0.088739     0.092863     -0.092597
# 26    0.939469       0.436816       -0.411002     0.417935     -0.395189
# 27    0.853766       0.351868        0.338031     0.011595     -0.011594
# 28    0.011480       0.001342        0.001342     0.882355      0.707597
# 29   -0.526004       1.929235        0.958672     1.451231      0.895936
# ...        ...            ...             ...          ...           ...
# 4868  0.667522       1.315815        0.865739     0.232210      0.228124
# 4869  0.011480       0.176605        0.174791     0.580471     -0.523008
# 4870 -0.248156       1.137868       -0.813695     0.760453      0.641343
# 4871  0.834765       0.527131        0.483185     1.248061      0.847739
# 4872 -0.309216       0.965289        0.746627     0.661739     -0.579520
# 4873  0.734635       0.264236        0.258254     1.126159      0.809701
# 4874  0.963917       0.001342        0.001342     0.417935     -0.395189
# 4875 -0.423658       0.699710       -0.604184     0.661739     -0.579520
# 4876  0.813543       0.877657        0.705244     0.882355      0.707597
# 4877  0.387513       1.137868       -0.813695     1.393152     -0.883863
# 4878  0.329831       1.225500       -0.841269     0.824276     -0.677390
# 4879 -0.248156       0.088973        0.088739     0.797186     -0.662461
# 4880 -0.248156       0.088973        0.088739     0.797186     -0.662461
# 4881 -0.654597       0.088973        0.088739     0.905544     -0.718987
# 4882  0.442312       0.962605       -0.745437     0.150942      0.149806
# 4883  0.493997       1.225500       -0.841269     0.801087      0.664644
# 4884 -0.309216       0.088973        0.088739     0.743008     -0.630959
# 4885 -0.248156       0.088973        0.088739     0.783642     -0.654792
# 4886  0.142958       5.171602        0.999936     1.329329      0.869085
# 4887 -0.753928       2.630288        0.989669     2.020108      0.965421
# 4888 -0.753928       0.439499        0.413229     1.068080     -0.788737
# 4889 -0.654597       0.088973        0.088739     0.905544     -0.718987
# 4890 -0.690825       0.436816       -0.411002     1.044891      0.779812
# 4891  0.329831       0.261553       -0.255747     0.069674      0.069561
# 4892  0.587472       0.439499        0.413229     0.661739     -0.579520
# 4893  0.493997       0.088973        0.088739     0.557282      0.505958
# 4894 -0.248156       0.261553       -0.255747     0.743008     -0.630959
# 4895 -0.865071       0.261553       -0.255747     0.905544     -0.718987
# 4896  0.763667       0.962605       -0.745437     1.857572      0.952454
# 4897  0.442312       1.488394       -0.903029     1.044891      0.779812
#
# [4898 rows x 33 columns]

# %%
trainX_ex, testX_ex = train_test_split(X_extend, random_state=42)

# %%
for alpha in [0., 0.001, 0.01, 0.1, 1, 10, 100]:
    linear_reg = Ridge(alpha)
    linear_reg.fit(trainX_ex, trainY)
    print alpha, '\t', mean_squared_error(testY, linear_reg.predict(testX_ex))
# Out:
# 0.0 	0.516931032212
# 0.001 	0.516931019462
# 0.01 	0.516930904672
# 0.1 	0.516929753694
# 1 	0.516918023577
# 10 	0.516826197999
# 100 	0.518524350888
