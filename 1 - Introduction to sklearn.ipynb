# %% [markdown]
# ## Hi, sklearn!

# %% [markdown]
# ## Reading spam collection

# %%
# !head -n 40 ./data/1-sms-spam-train.txt
# Out:
# ham	Did he say how fantastic I am by any chance, or anything need a bigger life lift as losing the will 2 live, do you think I would be the first person 2 die from N V Q?
# ham	Black shirt n blue jeans... I thk i c Ã¼...
# ham	If e timing can, then i go w u lor...
# ham	They r giving a second chance to rahul dengra.
# ham	I cant pick the phone right now. Pls send a message
# ham	Haha good to hear, I'm officially paid and on the market for an 8th
# ham	Ffffffffff. Alright no way I can meet up with you sooner?
# ham	But i'm really really broke oh. No amount is too small even  &lt;#&gt;
# ham	Only 2% students solved this CAT question in 'xam... 5+3+2= &lt;#&gt;  9+2+4= &lt;#&gt;  8+6+3= &lt;#&gt;  then 7+2+5=????? Tell me the answer if u r brilliant...1thing.i got d answr.
# spam	<Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert. You have 4 messages. You have 21 matches. Please call back on 09056242159 to retrieve your messages and matches
# ham	No da:)he is stupid da..always sending like this:)don believe any of those message.pandy is a mental:)
# spam	You won't believe it but it's true. It's Incredible Txts! Reply G now to learn truly amazing things that will blow your mind. From O2FWD only 18p/txt
# ham	It's fine, imma get a drink or somethin. Want me to come find you?
# ham	I can probably come by, everybody's done around  &lt;#&gt;  right?
# spam	sexy sexy cum and text me im wet and warm and ready for some porn! u up for some fun? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# ham	K, jason says he's gonna be around so I'll be up there around  &lt;#&gt;
# ham	Mon okie lor... Haha, best is cheap n gd food la, ex oso okie... Depends on whether wana eat western or chinese food... Den which u prefer...
# ham	Thats cool! Sometimes slow and gentle. Sonetimes rough and hard :)
# ham	Can you do online transaction?
# ham	Hows that watch resizing
# ham	Yes princess! I want to catch you with my big strong hands...
# ham	Ha ha cool cool chikku chikku:-):-DB-)
# ham	Yar... I tot u knew dis would happen long ago already.
# ham	If you r @ home then come down within 5 min
# ham	Haha get used to driving to usf man, I know a lot of stoners
# ham	He is impossible to argue with and he always treats me like his sub, like he never released me ... Which he did and I will remind him of that if necessary
# ham	Shuhui say change 2 suntec steamboat? U noe where? Where r u now?
# ham	In other news after hassling me to get him weed for a week andres has no money. HAUGHAIGHGTUJHYGUJ
# ham	I've sent Ã¼ my part..
# ham	I'll text now! All creepy like so he won't think that we forgot
# ham	Want to send me a virtual hug?... I need one
# ham	How will I creep on you now? ;_;
# ham	He said that he had a right giggle when he saw u again! You would possibly be the first person2die from NVQ, but think how much you could for!
# ham	I ask if u meeting da ge tmr nite...
# spam	FREE camera phones with linerental from 4.49/month with 750 cross ntwk mins. 1/2 price txt bundle deals also avble. Call 08001950382 or call2optout/J MF
# ham	Is that on the telly? No its Brdget Jones!
# ham	Hey darlin.. i can pick u up at college if u tell me wen & where 2 mt.. love Pete xx
# ham	aathi..where are you dear..
# ham	soon you will have the real thing princess! Do i make you wet? :)
# ham	If you can make it any time tonight or whenever you can it's cool, just text me whenever you're around

# %%
import codecs

with codecs.open('./data/1-sms-spam-train.txt') as f:
    labels, messages = zip(*[line.split('\t') for line in f.readlines()])

# %% [markdown]
# #### read test dataset

# %%
with codecs.open('./data/1-sms-spam-test.txt') as f:
    kaggle_test_messages = f.readlines()

# %% [markdown]
# #### prepare solution

# %%
import numpy

# %%
import pandas
from IPython.display import FileLink

def create_solution(predictions, filename='1-sms-spam-predictions.csv'):
    result = pandas.DataFrame({'Id': numpy.arange(len(predictions)), 'Label': predictions})
    result.to_csv('data/{}'.format(filename), index=False)
    return FileLink('data/{}'.format(filename))

# %%
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
def compute_data_expressions(messages):
    features = []
    # length of each string
    features.append(map(len, messages))
    
    # number of letters, digits, spaces = words
    for pattern in [str.isalpha, str.isdigit, str.isspace]:
        features.append(map(lambda message: sum(map(pattern, message)), messages))
        
    features = numpy.array(features).T
    return features

features = compute_data_expressions(messages)
kaggle_test_features = compute_data_expressions(kaggle_test_messages)

answers = numpy.array(labels) == 'spam'

# %%
features
# Out:
# array([[169, 124,   2,  40],
#        [ 45,  26,   0,  11],
#        [ 39,  24,   0,  11],
#        ...,
#        [ 32,  22,   0,   7],
#        [176, 119,  21,  29],
#        [ 26,  20,   0,   6]])

# %%
from sklearn.neighbors import KNeighborsClassifier
# area under the roc curve
from sklearn.metrics import roc_auc_score
knn_clf = KNeighborsClassifier(n_neighbors=1)
knn_clf.fit(features, answers)
roc_auc_score(answers, knn_clf.predict_proba(features)[:, 1])
# Out:
# 0.997237808402064

# %%
create_solution(knn_clf.predict_proba(kaggle_test_features)[:, 1])
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %%
trainX, testX, trainY, testY = train_test_split(features, answers, random_state=42)

# %% [markdown]
# ## Knn

# %%
knn_clf = KNeighborsClassifier(n_neighbors=1)
knn_clf.fit(trainX, trainY)
print 'test', roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
# print 'train', roc_auc_score(trainY, knn_clf.predict_proba(trainX)[:, 1])
# Out:
# test 0.935098650052

# %% [markdown]
# ## Finding optimal number of neighbours:

# %%
for n_neighbors in [1, 2, 4, 8, 16, 32, 64]:
    knn_clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn_clf.fit(trainX, trainY)
    print n_neighbors, roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
# Out:
# 1 0.935098650052
# 2 0.953595534787
# 4 0.967989211953
# 8 0.968775239414
# 16 0.976476866274
# 32 0.981092073382
# 64 0.974277431637

# %% [markdown]
# ### what happens if the metric is changed?

# %%
knn_clf = KNeighborsClassifier(metric='canberra', n_neighbors=20)
knn_clf.fit(trainX, trainY)
print roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
print roc_auc_score(trainY, knn_clf.predict_proba(trainX)[:, 1])
# Out:
# 0.983305930541
# 0.989802797453

# %% [markdown]
# ## Bag of words

# %%
vectorizer = CountVectorizer()
vectorizer.fit(messages)
counts = vectorizer.transform(messages).toarray()
test_counts = vectorizer.transform(kaggle_test_messages).toarray()

# %%
vectorizer.fit_transform(messages)
vocab = vectorizer.get_feature_names()
#print vocab
print counts.shape
# Out:
# (3000L, 6294L)

# %%
# vocabulary is dictionary which keeps correspondence between columns and words
# vectorizer.vocabulary_

# %%
trainX, testX, trainY, testY = train_test_split(counts, answers, random_state=42)

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# #### gaussian

# %%
from sklearn.naive_bayes import GaussianNB
nb_clf = GaussianNB()
nb_clf.fit(trainX, trainY)
roc_auc_score(testY, nb_clf.predict_proba(testX)[:, 1])
# Out:
# 0.88849948078920049

# %% [markdown]
# #### multinomial

# %%
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB()
nb_clf.fit(trainX, trainY)
roc_auc_score(testY, nb_clf.predict_proba(testX)[:, 1])
# Out:
# 0.98129398869274254

# %%
trainX.shape
# Out:
# (2250L, 6294L)

# %% [markdown]
# ## Linear regression + Ridge regularization

# %%
from sklearn.linear_model import Ridge

# %%
ridge_clf = Ridge()
ridge_clf.fit(trainX, trainY)
print roc_auc_score(testY, ridge_clf.predict(testX))
print roc_auc_score(trainY, ridge_clf.predict(trainX))
# Out:
# 0.989976347064
# 1.0

# %% [markdown]
# ** Exercise #0.** Play with regularization parameter of RidgeRegression, see how it affects quality on train and test.
# Check quality of best model by submitting to kaggle.

# %%
ridgetest = []
for alpha in numpy.arange(0,500,10):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest.append([alpha,aa,bb,aa+bb])
    #print alpha, roc_auc_score(testY, ridge_clf.predict(testX)), roc_auc_score(trainY, ridge_clf.predict(trainX)) 
ridgetest
## alpha = 20
# Out:
# [[0, 1.0, 0.98146705895927067, 1.9814670589592707],
#  [10, 1.0, 0.99443290642667592, 1.9944329064266759],
#  [20, 0.99995300828319378, 0.99537037037037046, 1.9953233786535642],
#  [30, 0.99979938151671188, 0.99545690550363453, 1.9952562870203465],
#  [40, 0.99958611141736053, 0.99522614514826346, 1.9948122565656239],
#  [50, 0.99928608737929003, 0.99502422983731398, 1.9943103172166041],
#  [60, 0.9989463011193066, 0.99472135687088958, 1.9936676579901962],
#  [70, 0.99851795354688067, 0.99438963886004395, 1.9929075924069246],
#  [80, 0.99801731102552194, 0.99402907580477673, 1.9920463868302987],
#  [90, 0.99754197173628967, 0.99361082266066691, 1.9911527943969567],
#  [100, 0.99706121032588768, 0.9932935271720319, 1.9903547374979196],
#  [110, 0.99652261295633937, 0.99301949925002886, 1.9895421122063683],
#  [120, 0.99604004417221381, 0.99278873889465791, 1.9888287830668716],
#  [130, 0.99554843851947172, 0.99241375331718018, 1.9879621918366519],
#  [140, 0.99503514438204976, 0.99213972539517714, 1.9871748697772269],
#  [150, 0.99452727236579797, 0.99170704972885659, 1.9862343220946546],
#  [160, 0.99409169529847874, 0.99153397946232835, 1.985625674760807],
#  [170, 0.99360912651435329, 0.99127437406253605, 1.9848835005768892],
#  [180, 0.99311209874044126, 0.99102919118495436, 1.9841412899253956],
#  [190, 0.99271989864248145, 0.99087054344063685, 1.9835904420831183],
#  [200, 0.99226805521165251, 0.99058209299642319, 1.9828501482080756],
ridge_clf.fit(trainX, trainY)
create_solution(ridge_clf.predict(test_counts))
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %% [markdown]
# **Exercise #1.** Let's write the correspondence between columns and words (done below). Which words are most popular?

# %%
dictionary = numpy.empty(len(vectorizer.vocabulary_), dtype='O')
for word, index in vectorizer.vocabulary_.iteritems():
    dictionary[index] = word

# %%
# computing number of times each word met in the training dataset:
word_counts = counts.sum(axis=0)
print word_counts
# printing only words that occured more than 100 times
print dictionary[word_counts > 100]
# Out:
# [ 4 15  1 ...,  1  1  1]
# [u'all' u'am' u'and' u'are' u'at' u'be' u'but' u'by' u'call' u'can' u'come'
#  u'day' u'do' u'for' u'free' u'from' u'get' u'go' u'good' u'got' u'gt'
#  u'have' u'he' u'how' u'if' u'in' u'is' u'it' u'its' u'just' u'know'
#  u'like' u'll' u'love' u'lt' u'me' u'my' u'no' u'not' u'now' u'of' u'ok'
#  u'on' u'only' u'or' u'out' u'send' u'so' u'text' u'that' u'the' u'then'
#  u'there' u'this' u'time' u'to' u'up' u'ur' u'want' u'was' u'we' u'what'
#  u'when' u'will' u'with' u'you' u'your']

# %%
words_ordered_by_occurences = dictionary[numpy.argsort(word_counts)]
print words_ordered_by_occurences[-50:]
# Out:
# [u'free' u'day' u'good' u'out' u'll' u'go' u'ok' u'from' u'what' u'up'
#  u'all' u'when' u'how' u'this' u'gt' u'lt' u'no' u'with' u'or' u'ur' u'get'
#  u'just' u'will' u'be' u'we' u'if' u'at' u'but' u'not' u'do' u'so' u'can'
#  u'are' u'now' u'on' u'call' u'that' u'of' u'have' u'for' u'your' u'it'
#  u'my' u'me' u'in' u'is' u'and' u'the' u'you' u'to']

# %%
dist = numpy.sum(counts, axis=0)
#vocab = vectorizer.get_feature_names()
word_frq = []
for tag, count in zip(dictionary, dist):
    word_frq.append([count, tag])
    # print count, tag
word_frq.sort(reverse=True)
word_frq
# Out:
# [[1176, u'to'],
#  [1156, u'you'],
#  [715, u'the'],
#  [510, u'and'],
#  [483, u'is'],
#  [470, u'in'],
#  [427, u'me'],
#  [415, u'my'],
#  [391, u'it'],
#  [373, u'your'],
#  [368, u'for'],
#  [322, u'have'],
#  [321, u'of'],
#  [306, u'that'],
#  [296, u'call'],
#  [286, u'on'],
#  [278, u'now'],
#  [263, u'are'],
#  [260, u'can'],
#  [245, u'so'],
#  [229, u'not'],
#  [229, u'do'],
#  [227, u'but'],
#  [223, u'at'],
#  [220, u'if'],
#  [218, u'we'],
#  [215, u'be'],
#  [207, u'will'],
#  [206, u'just'],
#  [206, u'get'],
#  [205, u'ur'],
#  [203, u'with'],
#  [203, u'or'],
#  [202, u'no'],
#  [186, u'lt'],
#  [185, u'gt'],
#  [179, u'this'],
#  [168, u'how'],
#  [167, u'when'],
#  [164, u'all'],
#  [160, u'up'],
#  [159, u'what'],
#  [158, u'ok'],
#  [158, u'from'],
#  [157, u'go'],
#  [155, u'll'],
#  [149, u'out'],
#  [147, u'good'],
#  [143, u'day'],
#  [140, u'free'],
#  [136, u'come'],
#  [134, u'like'],
#  [134, u'know'],
#  [130, u'there'],
#  [126, u'its'],
#  [125, u'time'],
#  [125, u'then'],
#  [118, u'got'],
#  [116, u'was'],
#  [115, u'am'],
#  [109, u'only'],
#  [105, u'send'],
#  [104, u'love'],
#  [102, u'want'],
#  [102, u'he'],
#  [101, u'text'],
#  [101, u'by'],
#  [99, u'lor'],
#  [96, u'txt'],
#  [93, u'need'],
#  [93, u'as'],
#  [90, u'one'],
#  [90, u'going'],
#  [88, u'stop'],
#  [86, u'think'],
#  [86, u'home'],
#  [86, u'about'],
#  [83, u'still'],
#  [83, u'sorry'],
#  [83, u'see'],
#  [82, u'da'],
#  [81, u'take'],
#  [81, u'she'],
#  [80, u'they'],
#  [80, u'pls'],
#  [80, u'don'],
#  [78, u'back'],
#  [77, u'well'],
#  [77, u'tell'],
#  [77, u'been'],
#  [76, u'hi'],
#  [74, u'her'],
#  [73, u'today'],
#  [73, u'mobile'],
#  [71, u'week'],
#  [70, u're'],
#  [69, u'later'],
#  [69, u'here'],
#  [69, u'claim'],
#  [68, u'reply'],
#  [68, u'happy'],
#  [68, u'any'],
#  [67, u'night'],
#  [67, u'dont'],
#  [66, u'where'],
#  [66, u'please'],
#  [66, u'great'],
#  [65, u'who'],
#  [65, u'new'],
#  [65, u'did'],
#  [64, u'wat'],
#  [64, u'some'],
#  [64, u'our'],
#  [64, u'hope'],
#  [63, u'phone'],
#  [62, u'way'],
#  [62, u'him'],
#  [62, u'hey'],
#  [62, u'has'],
#  [62, u'dear'],
#  [62, u'an'],
#  [60, u'msg'],
#  [59, u'more'],
#  [59, u'give'],
#  [58, u'should'],
#  [58, u'oh'],
#  [57, u'www'],
#  [56, u'work'],
#  [56, u'im'],
#  [56, u'had'],
#  [55, u'prize'],
#  [55, u'make'],
#  [54, u'said'],
#  [54, u'right'],
#  [54, u'really'],
#  [54, u'message'],
#  [53, u'won'],
#  [53, u'doing'],
#  [53, u'after'],
#  [52, u'much'],
#  [51, u've'],
#  [51, u'tomorrow'],
#  [50, u'number'],
#  [47, u'yeah'],
#  [47, u'too'],
#  [47, u'ask'],
#  [47, u'anything'],
#  [46, u'cash'],
#  [45, u'meet'],
#  [45, u'let'],
#  [45, u'find'],
#  [44, u'say'],
#  [44, u'last'],
#  [43, u'morning'],
#  [43, u'care'],
#  [43, u'amp'],
#  [42, u'very'],
#  [42, u'thanks'],
#  [42, u'sure'],
#  [41, u'would'],
#  [41, u'win'],
#  [41, u'them'],
#  [41, u'lol'],
#  [41, u'com'],
#  [41, u'already'],
#  [41, u'150p'],
#  [40, u'yes'],
#  [40, u'uk'],
#  [40, u'something'],
#  [40, u'cant'],
#  [40, u'babe'],
#  [40, u'again'],
#  [39, u'every'],
#  [39, u'also'],
#  [38, u'why'],
#  [38, u'sent'],
#  [38, u'cos'],
#  [37, u'wait'],
#  [37, u'urgent'],
#  [37, u'around'],
#  [37, u'50'],
#  [36, u'life'],
#  [36, u'customer'],
#  [36, u'buy'],
#  [36, u'before'],
#  [35, u'which'],
#  [35, u'were'],
#  [35, u'went'],
#  [35, u'tonight'],
#  [35, u'over'],
#  [35, u'nice'],
#  [35, u'keep'],
#  [34, u'wish'],
#  [34, u'place'],
#  [34, u'help'],
#  [34, u'gonna'],
#  [34, u'contact'],
#  [34, u'always'],
#  [33, u'down'],
#  [32, u'tone'],
#  [32, u'someone'],
#  [32, u'pick'],
#  [32, u'other'],
#  [32, u'min'],
#  [32, u'chat'],
#  [32, u'bit'],
#  [32, u'18'],
#  [31, u'year'],
#  [31, u'wan'],
#  [31, u'us'],
#  [31, u'thing'],
#  [31, u'off'],
#  [31, u'nokia'],
#  [31, u'leave'],
#  [31, u'gud'],
#  [31, u'fine'],
#  [31, u'feel'],
#  [31, u'cool'],
#  [31, u'co'],
#  [30, u'yup'],
#  [30, u'sleep'],
#  [30, u'ready'],
#  [30, u'miss'],
#  [30, u'getting'],
#  [30, u'could'],
#  [30, u'16'],
#  [29, u'per'],
#  [29, u'next'],
#  [29, u'many'],
#  [29, u'house'],
#  [29, u'holiday'],
#  [29, u'heart'],
#  [29, u'god'],
#  [28, u'yet'],
#  [28, u'thk'],
#  [28, u'soon'],
#  [28, u'service'],
#  [28, u'haha'],
#  [28, u'guaranteed'],
#  [28, u'first'],
#  [28, u'dun'],
#  [27, u'waiting'],
#  [27, u'sms'],
#  [27, u'people'],
#  [27, u'may'],
#  [27, u'hello'],
#  [27, u'friends'],
#  [27, u'even'],
#  [27, u'coming'],
#  [27, u'better'],
#  [26, u'try'],
#  [26, u'told'],
#  [26, u'things'],
#  [26, u'talk'],
#  [26, u'stuff'],
#  [26, u'smile'],
#  [26, u'probably'],
#  [26, u'money'],
#  [26, u'long'],
#  [26, u'didn'],
#  [26, u'awarded'],
#  [25, u'thought'],
#  [25, u'sweet'],
#  [25, u'receive'],
#  [25, u'name'],
#  [25, u'man'],
#  [25, u'lunch'],
#  [25, u'lot'],
#  [25, u'line'],
#  [25, u'cs'],
#  [25, u'ah'],
#  [25, u'500'],
#  [24, u'wk'],
#  [24, u'than'],
#  [24, u'special'],
#  [24, u'nothing'],
#  [24, u'never'],
#  [24, u'meeting'],
#  [24, u'ever'],
#  [24, u'draw'],
#  [24, u'chance'],
#  [23, u'thats'],
#  [23, u'selected'],
#  [23, u'same'],
#  [23, u'mind'],
#  [23, u'late'],
#  [23, u'his'],
#  [23, u'having'],
#  [23, u'friend'],
#  [23, u'birthday'],
#  [23, u'100'],
#  [23, u'10'],
#  [22, u'sir'],
#  [22, u'shit'],
#  [22, u'live'],
#  [22, u'liao'],
#  [22, u'half'],
#  [22, u'end'],
#  [22, u'eat'],
#  [22, u'car'],
#  [22, u'award'],
#  [22, u'aight'],
#  [22, u'1000'],
#  [21, u'ya'],
#  [21, u'wanna'],
#  [21, u'sat'],
#  [21, u'person'],
#  [21, u'little'],
#  [21, u'ill'],
#  [21, u'guess'],
#  [21, u'finish'],
#  [21, u'den'],
#  [21, u'dat'],
#  [21, u'cost'],
#  [21, u'camera'],
#  [21, u'best'],
#  [21, u'because'],
#  [21, u'account'],
#  [21, u'1st'],
#  [20, u'world'],
#  [20, u'word'],
#  [20, u'wont'],
#  [20, u'weekend'],
#  [20, u'watch'],
#  [20, u'trying'],
#  [20, u'start'],
#  [20, u'school'],
#  [20, u'plan'],
#  [20, u'left'],
#  [20, u'guys'],
#  [20, u'enjoy'],
#  [20, u'does'],
#  [20, u'dinner'],
#  [20, u'days'],
#  [20, u'class'],
#  [20, u'baby'],
#  [19, u'while'],
#  [19, u'speak'],
#  [19, u'shows'],
#  [19, u'month'],
#  [19, u'minutes'],
#  [19, u'luv'],
#  [19, u'landline'],
#  [19, u'important'],
#  [19, u'hear'],
#  [19, u'done'],
#  [19, u'bt'],
#  [19, u'box'],
#  [19, u'being'],
#  [19, u'apply'],
#  [18, u'xxx'],
#  [18, u'thanx'],
#  [18, u'thank'],
#  [18, u'real'],
#  [18, u'quite'],
#  [18, u'problem'],
#  [18, u'princess'],
#  [18, u'po'],
#  [18, u'play'],
#  [18, u'lar'],
#  [18, u'into'],
#  [18, u'fun'],
#  [18, u'easy'],
#  [18, u'early'],
#  [18, u'details'],
#  [18, u'code'],
#  [18, u'check'],
#  [18, u'big'],
#  [18, u'another'],
#  [18, u'actually'],
#  [18, u'2nd'],
#  [18, u'150ppm'],
#  [17, u'yo'],
#  [17, u'without'],
#  [17, u'use'],
#  [17, u'tv'],
#  [17, u'says'],
#  [17, u'plz'],
#  [17, u'pay'],
#  [17, u'pa'],
#  [17, u'missing'],
#  [17, u'mins'],
#  [17, u'job'],
#  [17, u'hour'],
#  [17, u'forgot'],
#  [17, u'few'],
#  [17, u'evening'],
#  [17, u'dunno'],
#  [17, u'dreams'],
#  [16, u'wife'],
#  [16, u'town'],
#  [16, u'tmr'],
#  [16, u'times'],
#  [16, u'ringtone'],
#  [16, u'put'],
#  [16, u'okie'],
#  [16, u'okay'],
#  [16, u'office'],
#  [16, u'might'],
#  [16, u'messages'],
#  [16, u'maybe'],
#  [16, u'kiss'],
#  [16, u'feeling'],
#  [16, u'bus'],
#  [16, u'boy'],
#  [16, u'bad'],
#  [16, u'afternoon'],
#  [15, u'until'],
#  [15, u'true'],
#  [15, u'top'],
#  [15, u'room'],
#  [15, u'rite'],
#  [15, u'remember'],
#  [15, u'reach'],
#  [15, u'rate'],
#  [15, u'must'],
#  [15, u'movie'],
#  [15, u'most'],
#  [15, u'means'],
#  [15, u'latest'],
#  [15, u'juz'],
#  [15, u'hav'],
#  [15, u'guy'],
#  [15, u'gr8'],
#  [15, u'fuck'],
#  [15, u'food'],
#  [15, u'family'],
#  [15, u'driving'],
#  [15, u'dis'],
#  [15, u'dad'],
#  [15, u'coz'],
#  [15, u'collect'],
#  [15, u'between'],
#  [15, u'000'],
#  [14, u'years'],
#  [14, u'wot'],
#  [14, u'worry'],
#  [14, u'working'],
#  [14, u'valid'],
#  [14, u'those'],
#  [14, u'stay'],
#  [14, u'since'],
#  [14, u'shopping'],
#  [14, u'shop'],
#  [14, u'shall'],
#  [14, u'sexy'],
#  [14, u'orange'],
#  [14, u'once'],
#  [14, u'mob'],
#  [14, u'look'],
#  [14, u'jus'],
#  [14, u'hurt'],
#  [14, u'head'],
#  [14, u'haven'],
#  [14, u'girl'],
#  [14, u'gift'],
#  [14, u'friendship'],
#  [14, u'everything'],
#  [14, u'eve'],
#  [14, u'entry'],
#  [14, u'enough'],
#  [14, u'either'],
#  [14, u'decimal'],
#  [14, u'bring'],
#  [14, u'bored'],
#  [14, u'book'],
#  [14, u'bonus'],
#  [14, u'bed'],
#  [14, u'ard'],
#  [14, u'anyway'],
#  [14, u'alright'],
#  [14, u'abt'],
#  [14, u'250'],
#  [13, u'xmas'],
#  [13, u'weeks'],
#  [13, u'watching'],
#  [13, u'vouchers'],
#  [13, u'two'],
#  [13, u'todays'],
#  [13, u'til'],
#  [13, u'sad'],
#  [13, u'question'],
#  [13, u'pub'],
#  [13, u'pm'],
#  [13, u'oso'],
#  [13, u'online'],
#  [13, u'nite'],
#  [13, u'making'],
#  [13, u'http'],
#  [13, u'havent'],
#  [13, u'hard'],
#  [13, u'goin'],
#  [13, u'games'],
#  [13, u'drive'],
#  [13, u'colour'],
#  [13, u'collection'],
#  [13, u'club'],
#  [13, u'change'],
#  [13, u'calls'],
#  [13, u'called'],
#  [13, u'beautiful'],
#  [13, u'asked'],
#  [13, u'answer'],
#  [13, u'address'],
#  [13, u'350'],
#  [13, u'2000'],
#  [12, u'words'],
#  [12, u'wid'],
#  [12, u'whats'],
#  [12, u'wants'],
#  [12, u'update'],
#  [12, u'tones'],
#  [12, u'till'],
#  [12, u'texts'],
#  [12, u'test'],
#  [12, u'started'],
#  [12, u'sleeping'],
#  [12, u'set'],
#  [12, u'saying'],
#  [12, u'private'],
#  [12, u'pounds'],
#  [12, u'plus'],
#  [12, u'pics'],
#  [12, u'part'],
#  [12, u'pain'],
#  [12, u'national'],
#  [12, u'music'],
#  [12, u'missed'],
#  [12, u'mate'],
#  [12, u'made'],
#  [12, u'lose'],
#  [12, u'looking'],
#  [12, u'lei'],
#  [12, u'info'],
#  [12, u'id'],
#  [12, u'hungry'],
#  [12, u'hot'],
#  [12, u'hair'],
#  [12, u'haf'],
#  [12, u'full'],
#  [12, u'fri'],
#  [12, u'email'],
#  [12, u'dude'],
#  [12, u'college'],
#  [12, u'chikku'],
#  [12, u'awesome'],
#  [12, u'attempt'],
#  [12, u'angry'],
#  [12, u'8007'],
#  [12, u'800'],
#  [12, u'10p'],
#  [11, u'yesterday'],
#  [11, u'winner'],
#  [11, u'wif'],
#  [11, u'wen'],
#  [11, u'weekly'],
#  [11, u'voucher'],
#  [11, u'video'],
#  [11, u'valued'],
#  [11, u'trip'],
#  [11, u'treat'],
#  [11, u'tot'],
#  [11, u'thinking'],
#  [11, u'story'],
#  [11, u'statement'],
#  [11, u'sounds'],
#  [11, u'snow'],
#  [11, u'smiling'],
#  [11, u'show'],
#  [11, u'services'],
#  [11, u'search'],
#  [11, u'sae'],
#  [11, u'row'],
#  [11, u'post'],
#  [11, u'points'],
#  [11, u'pic'],
#  [11, u'order'],
#  [11, u'offer'],
#  [11, u'noe'],
#  [11, u'neva'],
#  [11, u'makes'],
#  [11, u'leh'],
#  [11, u'leaving'],
#  [11, u'least'],
#  [11, u'join'],
#  [11, u'hours'],
#  [11, u'goes'],
#  [11, u'girls'],
#  [11, u'friday'],
#  [11, u'finished'],
#  [11, u'each'],
#  [11, u'didnt'],
#  [11, u'date'],
#  [11, u'congratulations'],
#  [11, u'calling'],
#  [11, u'brother'],
#  [11, u'believe'],
#  [11, u'await'],
#  [11, u'able'],
#  [11, u'86688'],
#  [11, u'150'],
#  [11, u'11'],
#  [10, u'xx'],
#  [10, u'wil'],
#  [10, u'welcome'],
#  [10, u'wana'],
#  [10, u'wake'],
#  [10, u'used'],
#  [10, u'touch'],
#  [10, u'though'],
#  [10, u'these'],
#  [10, u'sis'],
#  [10, u'saw'],
#  [10, u'rs'],
#  [10, u'price'],
#  [10, u'player'],
#  [10, u'parents'],
#  [10, u'network'],
#  [10, u'net'],
#  [10, u'minute'],
#  [10, u'mean'],
#  [10, u'mail'],
#  [10, u'ltd'],
#  [10, u'listen'],
#  [10, u'lesson'],
#  [10, u'land'],
#  [10, u'happiness'],
#  [10, u'expires'],
#  [10, u'else'],
#  [10, u'drop'],
#  [10, u'delivery'],
#  [10, u'decided'],
#  [10, u'de'],
#  [10, u'cum'],
#  [10, u'company'],
#  [10, u'comes'],
#  [10, u'choose'],
#  [10, u'charge'],
#  [10, u'cause'],
#  [10, u'carlos'],
#  [10, u'came'],
#  [10, u'break'],
#  [10, u'bout'],
#  [10, u'both'],
#  [10, u'away'],
#  [10, u'ass'],
#  [10, u'ago'],
#  [10, u'aft'],
#  [10, u'5000'],
#  [9, u'worth'],
#  [9, u'wkly'],
#  [9, u'within'],
#  [9, u'whole'],
#  [9, u'walk'],
#  [9, u'took'],
#  [9, u'tho'],
#  [9, u'th'],
#  [9, u'sun'],
#  [9, u'st'],
#  [9, u'smoke'],
#  [9, u'remove'],
#  [9, u'reason'],
#  [9, u'party'],
#  [9, u'outside'],
#  [9, u'opt'],
#  [9, u'old'],
#  [9, u'msgs'],
#  [9, u'mayb'],
#  [9, u'march'],
#  [9, u'lovely'],
#  [9, u'lost'],
#  [9, u'lets'],
#  [9, u'ipod'],
#  [9, u'il'],
#  [9, u'identifier'],
#  [9, u'hmv'],
#  [9, u'happened'],
#  [9, u'happen'],
#  [9, u'gas'],
#  [9, u'freemsg'],
#  [9, u'fancy'],
#  [9, u'face'],
#  [9, u'everyone'],
#  [9, u'drink'],
#  [9, u'dnt'],
#  [9, u'convey'],
#  [9, u'congrats'],
#  [9, u'chennai'],
#  [9, u'brings'],
#  [9, u'anyone'],
#  [9, u'12hrs'],
#  [8, u'yourself'],
#  [8, u'yours'],
#  [8, u'yar'],
#  [8, u'wow'],
#  [8, u'wonderful'],
#  [8, u'wishing'],
#  [8, u'wasn'],
#  [8, u'wanted'],
#  [8, u'unsubscribe'],
#  [8, u'type'],
#  [8, u'through'],
#  [8, u'ten'],
#  [8, u'tel'],
#  [8, u'takes'],
#  [8, u'swing'],
#  [8, u'surprise'],
#  [8, u'supposed'],
#  [8, u'support'],
#  [8, u'suite342'],
#  [8, u'somewhere'],
#  [8, u'slow'],
#  [8, u'second'],
#  [8, u'safe'],
#  [8, u'run'],
#  [8, u'red'],
#  [8, u'promise'],
#  [8, u'prob'],
#  [8, u'pretty'],
#  [8, u'press'],
#  [8, u'poly'],
#  [8, u'point'],
#  [8, u'park'],
#  [8, u'orchard'],
#  [8, u'numbers'],
#  [8, u'nt'],
#  [8, u'mu'],
#  [8, u'mom'],
#  [8, u'mates'],
#  [8, u'mah'],
#  [8, u'lucky'],
#  [8, u'loving'],
#  [8, u'lots'],
#  [8, u'loads'],
#  [8, u'kind'],
#  [8, u'invited'],
#  [8, u'huh'],
#  [8, u'hows'],
#  [8, u'hold'],
#  [8, u'hmmm'],
#  [8, u'hit'],
#  [8, u'heard'],
#  [8, u'grins'],
#  [8, u'gone'],
#  [8, u'glad'],
#  [8, u'found'],
#  [8, u'final'],
#  [8, u'felt'],
#  [8, u'empty'],
#  [8, u'earlier'],
#  [8, u'doesn'],
#  [8, u'difficult'],
#  [8, u'currently'],
#  [8, u'credit'],
#  [8, u'couple'],
#  [8, u'complimentary'],
#  [8, u'close'],
#  [8, u'christmas'],
#  [8, u'charged'],
#  [8, u'callertune'],
#  [8, u'busy'],
#  [8, u'bill'],
#  [8, u'bath'],
#  [8, u'balance'],
#  [8, u'askd'],
#  [8, u'alone'],
#  [8, u'87066'],
#  [8, u'750'],
#  [8, u'30'],
#  [8, u'2lands'],
#  [8, u'2003'],
#  [8, u'04'],
#  [7, u'yr'],
#  [7, u'wishes'],
#  [7, u'whatever'],
#  [7, u'wap'],
#  [7, u'via'],
#  [7, u'un'],
#  [7, u'ts'],
#  [7, u'truth'],
#  [7, u'tomo'],
#  [7, u'together'],
#  [7, u'tired'],
#  [7, u'thinks'],
#  [7, u'thinkin'],
#  [7, u'their'],
#  [7, u'terms'],
#  [7, u'telling'],
#  [7, u'tampa'],
#  [7, u'talking'],
#  [7, u'swt'],
#  [7, u'std'],
#  [7, u'specially'],
#  [7, u'sort'],
#  [7, u'somebody'],
#  [7, u'slowly'],
#  [7, u'side'],
#  [7, u'sex'],
#  [7, u'semester'],
#  [7, u'seen'],
#  [7, u'secret'],
#  [7, u'sea'],
#  [7, u'rest'],
#  [7, u'redeemed'],
#  [7, u'reading'],
#  [7, u'read'],
#  [7, u'pobox'],
#  [7, u'pix'],
#  [7, u'pass'],
#  [7, u'paper'],
#  [7, u'others'],
#  [7, u'oredi'],
#  [7, u'operator'],
#  [7, u'open'],
#  [7, u'ni8'],
#  [7, u'news'],
#  [7, u'mum'],
#  [7, u'mrt'],
#  [7, u'monday'],
#  [7, u'mine'],
#  [7, u'match'],
#  [7, u'luck'],
#  [7, u'lovable'],
#  [7, u'log'],
#  [7, u'lemme'],
#  [7, u'ive'],
#  [7, u'insurance'],
#  [7, u'ice'],
#  [7, u'hospital'],
#  [7, u'hoping'],
#  [7, u'hand'],
#  [7, u'ha'],
#  [7, u'gotta'],
#  [7, u'goodmorning'],
#  [7, u'gettin'],
#  [7, u'gd'],
#  [7, u'fucking'],
#  [7, u'frnds'],
#  [7, u'frm'],
#  [7, u'forget'],
#  [7, u'finally'],
#  [7, u'fantastic'],
#  [7, u'ex'],
#  [7, u'especially'],
#  [7, u'ending'],
#  [7, u'eg'],
#  [7, u'download'],
#  [7, u'doin'],
#  [7, u'dead'],
#  [7, u'dating'],
#  [7, u'darlin'],
#  [7, u'copy'],
#  [7, u'confirm'],
#  [7, u'computer'],
#  [7, u'comp'],
#  [7, u'caller'],
#  [7, u'bslvyl'],
#  [7, u'boytoy'],
#  [7, u'booked'],
#  [7, u'blue'],
#  [7, u'bcoz'],
#  [7, u'bb'],
#  [7, u'bathe'],
#  [7, u'bank'],
#  [7, u'bak'],
#  [7, u'area'],
#  [7, u'age'],
#  [7, u'0800'],
#  [6, u'yrs'],
#  [6, u'worried'],
#  [6, u'wit'],
#  [6, u'whenever'],
#  [6, u'warm'],
#  [6, u'w1j6hl'],
#  [6, u'vodafone'],
#  [6, u'vl'],
#  [6, u'visit'],
#  [6, u'valentines'],
#  [6, u'usual'],
#  [6, u'using'],
#  [6, u'usf'],
#  [6, u'urself'],
#  [6, u'tried'],
#  [6, u'tickets'],
#  [6, u'tea'],
#  [6, u'taking'],
#  [6, u'study'],
#  [6, u'straight'],
#  [6, u'starting'],
#  [6, u'south'],
#  [6, u'sofa'],
#  [6, u'smth'],
#  [6, u'slave'],
#  [6, u'sitting'],
#  [6, u'sister'],
#  [6, u'sick'],
#  [6, u'serious'],
#  [6, u'sending'],
#  [6, u'sch'],
#  [6, u'rock'],
#  [6, u'ring'],
#  [6, u'reveal'],
#  [6, u'request'],
#  [6, u'rental'],
#  [6, u'reference'],
#  [6, u'rather'],
#  [6, u'quiz'],
#  [6, u'questions'],
#  [6, u'plans'],
#  [6, u'persons'],
#  [6, u'paying'],
#  [6, u'own'],
#  [6, u'opinion'],
#  [6, u'ones'],
#  [6, u'o2'],
#  [6, u'nope'],
#  [6, u'nimya'],
#  [6, u'nah'],
#  [6, u'myself'],
#  [6, u'mp3'],
#  [6, u'move'],
#  [6, u'months'],
#  [6, u'mm'],
#  [6, u'met'],
#  [6, u'merry'],
#  [6, u'medical'],
#  [6, u'meant'],
#  [6, u'matches'],
#  [6, u'loved'],
#  [6, u'longer'],
#  [6, u'london'],
#  [6, u'loan'],
#  [6, u'lmao'],
#  [6, u'liked'],
#  [6, u'light'],
#  [6, u'la'],
#  [6, u'knows'],
#  [6, u'kinda'],
#  [6, u'jay'],
#  [6, u'isn'],
#  [6, u'inc'],
#  [6, u'honey'],
#  [6, u'hmm'],
#  [6, u'hiya'],
#  [6, u'hg'],
#  [6, u'gn'],
#  [6, u'ge'],
#  [6, u'game'],
#  [6, u'future'],
#  [6, u'fullonsms'],
#  [6, u'forwarded'],
#  [6, u'flower'],
#  [6, u'flirt'],
#  [6, u'feels'],
#  [6, u'fat'],
#  [6, u'fast'],
#  [6, u'etc'],
#  [6, u'entered'],
#  [6, u'england'],
#  [6, u'due'],
#  [6, u'double'],
#  [6, u'doesnt'],
#  [6, u'discount'],
#  [6, u'digital'],
#  [6, u'del'],
#  [6, u'deep'],
#  [6, u'decide'],
#  [6, u'cuz'],
#  [6, u'custcare'],
#  [6, u'crazy'],
#  [6, u'contract'],
#  [6, u'content'],
#  [6, u'comin'],
#  [6, u'colleagues'],
#  [6, u'coffee'],
#  [6, u'cine'],
#  [6, u'changed'],
#  [6, u'card'],
#  [6, u'cancel'],
#  [6, u'bother'],
#  [6, u'blood'],
#  [6, u'battery'],
#  [6, u'b4'],
#  [6, u'awaiting'],
#  [6, u'apartment'],
#  [6, u'anytime'],
#  [6, u'almost'],
#  [6, u'advance'],
#  [6, u'across'],
#  [6, u'abiola'],
#  [6, u'900'],
#  [6, u'87077'],
#  [6, u'50p'],
#  [6, u'4u'],
#  [6, u'20'],
#  [6, u'12'],
#  [6, u'11mths'],
#  [5, u'yep'],
#  [5, u'xy'],
#  [5, u'wrong'],
#  ...]

# %% [markdown]
# ** Exercise #2. ** By analyzing coefficients in `ridge_clf.coef_`, determine which words have the highest impact on decision (= have the largest modulus of `coef_`)

# %%
par_impact=zip(dictionary, ridge_clf.coef_)
par_impact_new=sorted(par_impact, key=lambda x: abs(x[1]), reverse=True)

# %%
par_impact_new
# Out:
# [(u'88066', 0.33813707390738645),
#  (u'85233', 0.26061762654494608),
#  (u'08719181503', 0.25921968176431959),
#  (u'voicemail', 0.25921968176431959),
#  (u'ringtone', 0.23698860702164426),
#  (u'service', 0.22746191611798694),
#  (u'ltd', 0.22429401256459078),
#  (u'barbie', 0.20343010646563695),
#  (u'ken', 0.20343010646563695),
#  (u'uk', 0.19701038442312094),
#  (u'announcement', 0.19687388348255602),
#  (u'dating', 0.19223628133933193),
#  (u'arsenal', 0.19159700218174794),
#  (u'repeat', 0.18998136078779398),
#  (u'private', 0.18963359075721684),
#  (u'08712402972', 0.18823223942767139),
#  (u'minmobsmorelkpobox177hp51fl', 0.18705047981478173),
#  (u'claim', 0.18214968976392065),
#  (u'50', 0.18052677336596029),
#  (u'statement', 0.1804202792460303),
#  (u'connected', 0.17416422506079668),
#  (u'gmw', 0.17416422506079668),
#  (u'2003', 0.17360700675800919),
#  (u'150p', 0.17223465970033397),
#  (u'truly', 0.17132384892746855),
#  (u'12', 0.16848584729728425),
#  (u'accordingly', 0.16674157052020661),
#  (u'mobile', 0.16630380235474615),
#  (u'078', 0.16567789021303334),
#  (u'urgent', 0.16334636461739363),
#  (u'immediately', 0.16310861165864277),
#  (u'sexy', 0.16152408131165893),
#  (u'http', 0.16122232198006248),
#  (u'collection', 0.16111918214887211),
#  (u'fullonsms', -0.15291944492175705),
#  (u'mob', 0.1486336664039731),
#  (u'fgkslpo', 0.14819703346197341),
#  (u'fgkslpopw', 0.14819703346197341),
#  (u'netun', 0.14819703346197341),
#  (u'shsex', 0.14819703346197341),
#  (u'videos', 0.14819703346197341),
#  (u'win', 0.14571316864917594),
#  (u'gbp', 0.14391857543622971),
#  (u'banned', 0.14194327338801377),
#  (u'lucy', 0.14024957809983141),
#  (u'delivery', 0.1394480772205465),
#  (u'sale', 0.13818081748683889),
#  (u'www', 0.13750449016636032),
#  (u'credit', 0.13432732609673845),
#  (u'august', 0.13392322410223609),
#  (u'ring', 0.13288845901852536),
#  (u'02073162414', 0.13267993427227856),
#  (u'explicit', 0.13267993427227856),
#  (u'secs', 0.13267993427227856),
#  (u'xxx', 0.13171063439514494),
#  (u'std', 0.12928841871183966),
#  (u'lookatme', 0.12890542353043466),
#  (u'premier', 0.12883765913044221),
#  (u'divorce', 0.12813645433745216),
#  (u'harry', 0.12679830943188236),
#  (u'currently', 0.1263449297862356),
#  (u'vodafone', 0.12628750289531174),
#  (u'500', 0.12525604915600252),
#  (u'bid', 0.12499430505872142),
#  (u'condition', 0.12479230806531073),
#  (u'dartboard', 0.12479230806531073),
#  (u'doubles', 0.12479230806531073),
#  (u'trebles', 0.12479230806531073),
#  (u'20p', 0.12430913990551667),
#  (u'brought', 0.12027791908427542),
#  (u'com', 0.11965454218841988),
#  (u'awarded', 0.11951645363515952),
#  (u'added', -0.11859655670603809),
#  (u'maniac', 0.11846587568701893),
#  (u'slower', 0.11846587568701893),
#  (u'coincidence', 0.11790058140207504),
#  (u'radio', 0.11790058140207504),
#  (u'teenager', 0.11769272526191116),
#  (u'nearly', 0.11756966144323051),
#  (u'new', 0.11745431458792631),
#  (u'attempt', 0.11634444179252472),
#  (u'notice', 0.11516669876388153),
#  (u'takes', 0.11487418057566127),
#  (u'cost', 0.1147745043279403),
#  (u'1000', 0.11412755705197786),
#  (u'apply', 0.11407949118275991),
#  (u'word', 0.11354843554327408),
#  (u'sing', 0.11279382691908606),
#  (u'txt', 0.11193071071287085),
#  (u'camera', 0.110567677372544),
#  (u'awaiting', 0.10995125700914575),
#  (u'faster', 0.10827196417432118),
#  (u'chg', 0.10663612195332912),
#  (u'cst', 0.10663612195332912),
#  (u'xafter', 0.10663612195332912),
#  (u'polys', 0.10608709476436408),
#  (u'bloomberg', 0.10572718554335404),
#  (u'costs', 0.10559279393416786),
#  (u'0800', 0.10525317151566804),
#  (u'rate', 0.10436291507208244),
#  (u'won', 0.10381799101957918),
#  (u'pics', 0.10355146807430163),
#  (u'dark', 0.10285289433654317),
#  (u'user', 0.10274624792081916),
#  (u'term', 0.10261002505905094),
#  (u'80488', 0.10255718589600532),
#  (u'forwarded', 0.10231903238717251),
#  (u'reply', 0.10193546850989488),
#  (u'slo', 0.10097610539665508),
#  (u'08718723815', 0.10028142770236462),
#  (u'250', 0.10009478916189311),
#  (u'2005', 0.099955662810777293),
#  (u'burger', 0.099215275240124898),
#  (u'sport', 0.098488780191659575),
#  (u'direct', 0.097980966262976157),
#  (u'incomm', -0.097933684081336528),
#  (u'costume', -0.032292956813768758),
#  (u'bigger', -0.032268757977022326),
#  (u'0871277810810', 0.032254621789467045),
#  (u'loads', -0.03221192436185652),
#  (u'09058091854', 0.032193241528216808),
#  (u'6wu', 0.032193241528216808),
#  (u'box385', 0.032193241528216808),
#  (u'm6', 0.032193241528216808),
#  (u'arrange', 0.032152917506355523),
#  (u'remind', 0.032147955076554408),
#  (u'ph', 0.032065959252524298),
#  (u'dentists', -0.032045298991418378),
#  (u'quote', 0.031981096834731271),
#  (u'arcade', 0.03197941221346786),
#  (u'aint', 0.031834602921304307),
#  (u'nelson', 0.031834602921304307),
#  (u'sleep', -0.031796830497378505),
#  (u'ts', -0.031788590637125337),
#  (u'across', -0.03178207737166356),
#  (u'mom', -0.031717243533935943),
#  (u'gorgeous', -0.031688671970015674),
#  (u'mwahs', -0.031688671970015674),
#  (u'squishy', -0.031688671970015674),
#  (u'pretty', -0.031666182922564103),
#  (u'bugis', -0.031592088493453109),
#  (u'12hrs', -0.031567048191412712),
#  (u'th', -0.031488578239510817),
#  (u'walls', -0.031437480149180456),
#  (u'asked', 0.031413779932401249),
#  (u'trust', 0.031387582220504431),
#  (u'cancer', -0.0313826342619027),
#  (u'09061701461', -0.031356530004289368),
#  (u'kl341', -0.031356530004289368),
#  (u'receivea', -0.031356530004289368),
#  (u'blackberry', -0.031275942308883295),
#  (u'82277', 0.0312634335805934),
#  (u'71', 0.031248576264680354),
#  (u'83383', 0.031248576264680354),
#  (u'bids', 0.031248576264680354),
#  (u'highest', 0.031248576264680354),
#  (u'maximum', 0.031248576264680354),
#  (u'custcare', 0.031191448161215475),
#  (u'england', 0.031166674056245874),
#  (u'walking', -0.031162744998542043),
#  (u'believe', 0.031141465728549644),
#  (u'actual', -0.031111274970355231),
#  (u'problem', -0.031062610820281111),
#  (u'end', 0.031061285778322768),
#  (u'co', 0.031058856807907795),
#  (u'right', -0.03104012098603897),
#  (u'someday', -0.030966319312015687),
#  (u'interested', 0.030946972968855648),
#  (u'coins', -0.03090994808792864),
#  (u'08712405022', 0.030897623339537068),
#  (u'80608', 0.030897623339537068),
#  (u'movietrivia', 0.030897623339537068),
#  (u'88877', 0.030816231109649712),
#  (u'left', -0.030808385342133319),
#  (u'jason', -0.030796184839889672),
#  (u'character', -0.030671810391237956),
#  (u'part', 0.030647121976434245),
#  (u'intro', -0.030643579406075202),
#  (u'please', 0.030568430047911901),
#  (u'havin', -0.030558516921846097),
#  (u'09066361921', 0.030443170223763177),
#  (u'mistake', 0.030440776876739691),
#  (u'06', 0.030405734012452612),
#  (u'drink', -0.030363005473382963),
#  (u'wonder', -0.030332905901198547),
#  (u'comedy', -0.030315043398759043),
#  (u'cute', 0.030271675246922144),
#  (u'cum', -0.030271437298734466),
#  (u'nudist', -0.030264062336080425),
#  (u'themed', -0.030264062336080425),
#  (u'adult', -0.030263903927786027),
#  (u'comment', -0.030263903927786027),
#  (u'danger', -0.030263903927786027),
#  (u'peeps', -0.030263903927786027),
#  (u'hsbc', -0.030252891434178523),
#  (u'caller', 0.030127036989056954),
#  (u'net', 0.030096140090512879),
#  (u'knowing', -0.030043682627815548),
#  (u'walked', -0.030005375419964606),
#  (u'raji', 0.02998733325541094),
#  (u'support', -0.02989049441035152),
#  (u'its', -0.029830065947665966),
#  (u'nuerologist', -0.029816206645737718),
#  (u'way', -0.02976626189658475),
#  (u'myself', 0.02974889272499422),
#  (u'must', 0.029747996168451706),
#  (u'pick', -0.02973181830906035),
#  (u'inches', 0.029730978339849189),
#  (u'catch', -0.029711185380138127),
#  (u'nt', -0.029704017034656229),
#  (u'start', -0.029630387765229457),
#  (u'elama', -0.02962786170531044),
#  (u'mudyadhu', -0.02962786170531044),
#  (u'stoners', -0.029508229922150027),
#  (u'07734396839', 0.0294995327846771),
#  (u'ibh', 0.0294995327846771),
#  (u'nokia6600', 0.0294995327846771),
#  (u'selection', 0.02949012418931872),
#  (u'babysitting', -0.029436533377068346),
#  ...]

# %% [markdown]
# ** Exercise #3. **  Does combining features and counts improve quality? Use `numpy.hstack` to concatenate arrays.
# Explain the result.

# %%
counts.shape, features.shape, numpy.hstack((counts,features)).shape

combined = numpy.hstack((counts,features))
trainX, testX, trainY, testY = train_test_split(combined, answers, random_state=42)

ridgetest = []
for alpha in [0.01, 0.1, 1, 10, 100, 1000]:
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest.append([alpha,aa,bb,aa+bb])
ridgetest
# Out:
# [[0.01, 1.0, 0.9905388254297911, 1.9905388254297911],
#  [0.1, 1.0, 0.9914041767624322, 1.9914041767624322],
#  [1, 1.0, 0.99190896503980608, 1.9919089650398061],
#  [10, 1.0, 0.99519730010384211, 1.9951973001038421],
#  [100, 0.99893907162441331, 0.99714434060228452, 1.9960834122266977],
#  [1000, 0.99123062269446893, 0.99610591900311518, 1.9873365416975841]]

# %%
ridgetest2 = []
for alpha in numpy.arange(10,100,10):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest2.append([alpha,aa,bb,aa+bb])
ridgetest2
# Out:
# [[10, 1.0, 0.99519730010384211, 1.9951973001038421],
#  [20, 0.99999457787882995, 0.9963655244029076, 1.9963601022817374],
#  [30, 0.99995662303064048, 0.99666839736933199, 1.9966250203999725],
#  [40, 0.99985721747585798, 0.99694242529133492, 1.996799642767193],
#  [50, 0.99973612343639584, 0.9970866505134417, 1.9968227739498374],
#  [60, 0.99958791879108388, 0.9971299180800739, 1.9967178368711578],
#  [70, 0.99945055838811192, 0.99711549555786316, 1.9965660539459751],
#  [80, 0.9992734357632268, 0.99714434060228452, 1.9964177763655113],
#  [90, 0.99912161637046815, 0.99715876312449525, 1.9962803794949635]]

# %%
ridgetest3 = []
for alpha in numpy.arange(20,30,1):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest3.append([alpha,aa,bb,aa+bb])
ridgetest3
# Out:
# [[20, 0.99999457787882995, 0.9963655244029076, 1.9963601022817374],
#  [21, 0.99999096313138347, 0.99643763701396093, 1.9964286001453444],
#  [22, 0.99999096313138347, 0.99645205953617166, 1.9964430226675551],
#  [23, 0.99998915575766012, 0.99652417214722511, 1.9965133279048852],
#  [24, 0.99998734838393677, 0.99652417214722511, 1.9965115205311619],
#  [25, 0.99998192626276683, 0.99656743971385719, 1.996549365976624],
#  [26, 0.99997469676787354, 0.99659628475827855, 1.9965709815261521],
#  [27, 0.99996927464670371, 0.99663955232491042, 1.996608826971614],
#  [28, 0.99996385252553366, 0.99665397484712126, 1.9966178273726549],
#  [29, 0.99996385252553366, 0.99663955232491053, 1.9966034048504442]]

# %%
ridgetest4 = []
for alpha in numpy.arange(20,21,0.1):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest4.append([alpha,aa,bb,aa+bb])
ridgetest4
# Out:
# [[20.0, 0.99999457787882995, 0.9963655244029076, 1.9963601022817374],
#  [20.100000000000001,
#   0.99999457787883017,
#   0.9963655244029076,
#   1.9963601022817379],
#  [20.200000000000003,
#   0.99999457787882995,
#   0.9963655244029076,
#   1.9963601022817374],
#  [20.300000000000004,
#   0.99999457787883017,
#   0.9963655244029076,
#   1.9963601022817379],
#  [20.400000000000006,
#   0.9999927705051066,
#   0.99637994692511822,
#   1.9963727174302248],
#  [20.500000000000007,
#   0.99999277050510682,
#   0.99637994692511822,
#   1.996372717430225],
#  [20.600000000000009,
#   0.99999277050510671,
#   0.99640879196953969,
#   1.9964015624746465],
#  [20.70000000000001,
#   0.99999277050510682,
#   0.9964232144917502,
#   1.996415984996857],
#  [20.800000000000011,
#   0.99999277050510682,
#   0.99642321449175042,
#   1.9964159849968572],
#  [20.900000000000013,
#   0.99999096313138347,
#   0.99642321449175031,
#   1.9964141776231337]]

# %%
sorted(ridgetest4,key=lambda x: x[3])
# Out:
# [[20.0, 0.99999457787882995, 0.9963655244029076, 1.9963601022817374],
#  [20.200000000000003,
#   0.99999457787882995,
#   0.9963655244029076,
#   1.9963601022817374],
#  [20.100000000000001,
#   0.99999457787883017,
#   0.9963655244029076,
#   1.9963601022817379],
#  [20.300000000000004,
#   0.99999457787883017,
#   0.9963655244029076,
#   1.9963601022817379],
#  [20.400000000000006,
#   0.9999927705051066,
#   0.99637994692511822,
#   1.9963727174302248],
#  [20.500000000000007,
#   0.99999277050510682,
#   0.99637994692511822,
#   1.996372717430225],
#  [20.600000000000009,
#   0.99999277050510671,
#   0.99640879196953969,
#   1.9964015624746465],
#  [20.900000000000013,
#   0.99999096313138347,
#   0.99642321449175031,
#   1.9964141776231337],
#  [20.70000000000001,
#   0.99999277050510682,
#   0.9964232144917502,
#   1.996415984996857],
#  [20.800000000000011,
#   0.99999277050510682,
#   0.99642321449175042,
#   1.9964159849968572]]

# %%
combined_test = numpy.hstack((test_counts,kaggle_test_features))
combined_train = numpy.hstack((counts,features))

ridge_clf = Ridge(alpha=43.5)
ridge_clf.fit(trainX, trainY)
create_solution(ridge_clf.predict(combined_test))
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %% [markdown]
# ** Exercise #4.** Print examples on which your classifier makes mistakes (both false positive and false negative).
#
# This is important step to understand what can be done to improve the classifier

# %%
metrics.f1_score(testY, ridge_clf.predict(testX))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-8908ba853c52> in <module>()
#       1
# ----> 2 metrics.f1_score(testY, ridge_clf.predict(testX))
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#     637     return fbeta_score(y_true, y_pred, 1, labels=labels,
#     638                        pos_label=pos_label, average=average,
# --> 639                        sample_weight=sample_weight)
#     640
#     641
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight)
#     754                                                  average=average,
#     755                                                  warn_for=('f-score',),
# --> 756                                                  sample_weight=sample_weight)
#     757     return f
#     758
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#     954         raise ValueError("beta should be >0 in the F-beta score")
#     955
# --> 956     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     957     present_labels = unique_labels(y_true, y_pred)
#     958
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in _check_targets(y_true, y_pred)
#      80     if len(y_type) > 1:
#      81         raise ValueError("Can't handle mix of {0} and {1}"
# ---> 82                          "".format(type_true, type_pred))
#      83
#      84     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Can't handle mix of binary and continuous

# %%
ridge_clf.predict("ahdhdk")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-e0d7c0bffc83> in <module>()
# ----> 1 ridge_clf.predict("ahdhdk")
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\linear_model\base.pyc in predict(self, X)
#     198             Returns predicted values.
#     199         """
# --> 200         return self._decision_function(X)
#     201
#     202     _center_data = staticmethod(center_data)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\linear_model\base.pyc in _decision_function(self, X)
#     183         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     184         return safe_sparse_dot(X, self.coef_.T,
# --> 185                                dense_output=True) + self.intercept_
#     186
#     187     def predict(self, X):
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\utils\extmath.pyc in safe_sparse_dot(a, b, dense_output)
#     182         return ret
#     183     else:
# --> 184         return fast_dot(a, b)
#     185
#     186
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('S32') according to the rule 'safe'

# %%
testX
# Out:
# array([[  0,   0,   0, ...,  63,   0,  17],
#        [  0,   0,   0, ...,  28,   0,   5],
#        [  0,   0,   0, ...,  26,   0,   6],
#        ...,
#        [  0,   0,   0, ...,  59,   0,  20],
#        [  0,   0,   0, ..., 101,  15,  36],
#        [  0,   0,   0, ...,  49,   1,  14]], dtype=int64)

# %%
## Confusion matrix
from sklearn import metrics
# testing score
score = metrics.confusion_matrix(testY, ridge_clf.predict(testX))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-5b0b96d967f7> in <module>()
#       2 from sklearn import metrics
#       3 # testing score
# ----> 4 score = metrics.confusion_matrix(testY, ridge_clf.predict(testX))
#       5
#       6
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in confusion_matrix(y_true, y_pred, labels)
#     231
#     232     """
# --> 233     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     234     if y_type not in ("binary", "multiclass"):
#     235         raise ValueError("%s is not supported" % y_type)
#
# C:\Users\Yanjie\Anaconda\lib\site-packages\sklearn\metrics\classification.pyc in _check_targets(y_true, y_pred)
#      80     if len(y_type) > 1:
#      81         raise ValueError("Can't handle mix of {0} and {1}"
# ---> 82                          "".format(type_true, type_pred))
#      83
#      84     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Can't handle mix of binary and continuous

# %% [markdown]
# ** Exercise #5. (optional, just for fun)**  write a spam SMS, which is not caught by your best model.
# Something like "Send sms YES to 091231323 to activate amazing spam filter, FREE for two weeks, then 20p/day. Txt now!".
#
# Use your knowledge about the structure of the model.

# %% [markdown]
# ** Major Goal (not in the homework). ** Provide best classification model for the problem.
#
# You can start with computing new features:
# 1. Computing occurences of symbols
# 2. Ignoring the words with digits, dots, etc.
# 3. Detect links, phones in text
#
# Or start with changing parameters of classifiers.
