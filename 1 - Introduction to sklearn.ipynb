# %% [markdown]
# ## Hi, sklearn!

# %% [markdown]
# ## Reading spam collection

# %%
# !head -n 40 ./data/1-sms-spam-train.txt
# Out:
# ham	Did he say how fantastic I am by any chance, or anything need a bigger life lift as losing the will 2 live, do you think I would be the first person 2 die from N V Q?
# ham	Black shirt n blue jeans... I thk i c Ã¼...
# ham	If e timing can, then i go w u lor...
# ham	They r giving a second chance to rahul dengra.
# ham	I cant pick the phone right now. Pls send a message
# ham	Haha good to hear, I'm officially paid and on the market for an 8th
# ham	Ffffffffff. Alright no way I can meet up with you sooner?
# ham	But i'm really really broke oh. No amount is too small even  &lt;#&gt;
# ham	Only 2% students solved this CAT question in 'xam... 5+3+2= &lt;#&gt;  9+2+4= &lt;#&gt;  8+6+3= &lt;#&gt;  then 7+2+5=????? Tell me the answer if u r brilliant...1thing.i got d answr.
# spam	<Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert. You have 4 messages. You have 21 matches. Please call back on 09056242159 to retrieve your messages and matches
# ham	No da:)he is stupid da..always sending like this:)don believe any of those message.pandy is a mental:)
# spam	You won't believe it but it's true. It's Incredible Txts! Reply G now to learn truly amazing things that will blow your mind. From O2FWD only 18p/txt
# ham	It's fine, imma get a drink or somethin. Want me to come find you?
# ham	I can probably come by, everybody's done around  &lt;#&gt;  right?
# spam	sexy sexy cum and text me im wet and warm and ready for some porn! u up for some fun? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# ham	K, jason says he's gonna be around so I'll be up there around  &lt;#&gt;
# ham	Mon okie lor... Haha, best is cheap n gd food la, ex oso okie... Depends on whether wana eat western or chinese food... Den which u prefer...
# ham	Thats cool! Sometimes slow and gentle. Sonetimes rough and hard :)
# ham	Can you do online transaction?
# ham	Hows that watch resizing
# ham	Yes princess! I want to catch you with my big strong hands...
# ham	Ha ha cool cool chikku chikku:-):-DB-)
# ham	Yar... I tot u knew dis would happen long ago already.
# ham	If you r @ home then come down within 5 min
# ham	Haha get used to driving to usf man, I know a lot of stoners
# ham	He is impossible to argue with and he always treats me like his sub, like he never released me ... Which he did and I will remind him of that if necessary
# ham	Shuhui say change 2 suntec steamboat? U noe where? Where r u now?
# ham	In other news after hassling me to get him weed for a week andres has no money. HAUGHAIGHGTUJHYGUJ
# ham	I've sent Ã¼ my part..
# ham	I'll text now! All creepy like so he won't think that we forgot
# ham	Want to send me a virtual hug?... I need one
# ham	How will I creep on you now? ;_;
# ham	He said that he had a right giggle when he saw u again! You would possibly be the first person2die from NVQ, but think how much you could for!
# ham	I ask if u meeting da ge tmr nite...
# spam	FREE camera phones with linerental from 4.49/month with 750 cross ntwk mins. 1/2 price txt bundle deals also avble. Call 08001950382 or call2optout/J MF
# ham	Is that on the telly? No its Brdget Jones!
# ham	Hey darlin.. i can pick u up at college if u tell me wen & where 2 mt.. love Pete xx
# ham	aathi..where are you dear..
# ham	soon you will have the real thing princess! Do i make you wet? :)
# ham	If you can make it any time tonight or whenever you can it's cool, just text me whenever you're around

# %%
import codecs

with codecs.open('./data/1-sms-spam-train.txt') as f:
    labels, messages = zip(*[line.split('\t') for line in f.readlines()])

# %% [markdown]
# #### read test dataset

# %%
with codecs.open('./data/1-sms-spam-test.txt') as f:
    kaggle_test_messages = f.readlines()

# %% [markdown]
# #### prepare solution

# %%
import numpy

# %%
import pandas
from IPython.display import FileLink

def create_solution(predictions, filename='1-sms-spam-predictions.csv'):
    result = pandas.DataFrame({'Id': numpy.arange(len(predictions)), 'Label': predictions})
    result.to_csv('data/{}'.format(filename), index=False)
    return FileLink('data/{}'.format(filename))

# %%
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
def compute_data_expressions(messages):
    features = []
    # length of each string
    features.append(map(len, messages))
    
    # number of letters, digits, spaces = words
    for pattern in [str.isalpha, str.isdigit, str.isspace]:
        features.append(map(lambda message: sum(map(pattern, message)), messages))
        
    features = numpy.array(features).T
    return features

features = compute_data_expressions(messages)
kaggle_test_features = compute_data_expressions(kaggle_test_messages)

answers = numpy.array(labels) == 'spam'

# %%
features
# Out:
# array([[169, 124,   2,  40],
#        [ 45,  26,   0,  11],
#        [ 39,  24,   0,  11],
#        ...,
#        [ 32,  22,   0,   7],
#        [176, 119,  21,  29],
#        [ 26,  20,   0,   6]])

# %%
from sklearn.neighbors import KNeighborsClassifier
# area under the roc curve
from sklearn.metrics import roc_auc_score
knn_clf = KNeighborsClassifier(n_neighbors=1)
knn_clf.fit(features, answers)
roc_auc_score(answers, knn_clf.predict_proba(features)[:, 1])
# Out:
# 0.997237808402064

# %%
create_solution(knn_clf.predict_proba(kaggle_test_features)[:, 1])
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %%
trainX, testX, trainY, testY = train_test_split(features, answers, random_state=42)

# %% [markdown]
# ## Knn

# %%
knn_clf = KNeighborsClassifier(n_neighbors=1)
knn_clf.fit(trainX, trainY)
print 'test', roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
# print 'train', roc_auc_score(trainY, knn_clf.predict_proba(trainX)[:, 1])
# Out:
# test 0.935098650052

# %% [markdown]
# ## Finding optimal number of neighbours:

# %%
for n_neighbors in [1, 2, 4, 8, 16, 32, 64]:
    knn_clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn_clf.fit(trainX, trainY)
    print n_neighbors, roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
# Out:
# 1 0.935098650052
# 2 0.953595534787
# 4 0.967989211953
# 8 0.968775239414
# 16 0.976476866274
# 32 0.981092073382
# 64 0.974277431637

# %% [markdown]
# ### what happens if the metric is changed?

# %%
knn_clf = KNeighborsClassifier(metric='canberra', n_neighbors=20)
knn_clf.fit(trainX, trainY)
print roc_auc_score(testY, knn_clf.predict_proba(testX)[:, 1])
print roc_auc_score(trainY, knn_clf.predict_proba(trainX)[:, 1])
# Out:
# 0.983305930541
# 0.989802797453

# %% [markdown]
# ## Bag of words

# %%
vectorizer = CountVectorizer()
vectorizer.fit(messages)
counts = vectorizer.transform(messages).toarray()
test_counts = vectorizer.transform(kaggle_test_messages).toarray()

# %%
vectorizer.fit_transform(messages)
vocab = vectorizer.get_feature_names()
#print vocab
print counts.shape
# Out:
# (3000L, 6294L)

# %%
# vocabulary is dictionary which keeps correspondence between columns and words
# vectorizer.vocabulary_

# %%
trainX, testX, trainY, testY = train_test_split(counts, answers, random_state=42)

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# #### gaussian

# %%
from sklearn.naive_bayes import GaussianNB
nb_clf = GaussianNB()
nb_clf.fit(trainX, trainY)
roc_auc_score(testY, nb_clf.predict_proba(testX)[:, 1])
# Out:
# 0.88849948078920049

# %% [markdown]
# #### multinomial

# %%
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB()
nb_clf.fit(trainX, trainY)
roc_auc_score(testY, nb_clf.predict_proba(testX)[:, 1])
# Out:
# 0.97836621668397372

# %%
trainX.shape
# Out:
# (2250L, 6294L)

# %% [markdown]
# ## Linear regression + Ridge regularization

# %%
from sklearn.linear_model import Ridge

# %%
ridge_clf = Ridge()
ridge_clf.fit(trainX, trainY)
print roc_auc_score(testY, ridge_clf.predict(testX))
print roc_auc_score(trainY, ridge_clf.predict(trainX))
# Out:
# 0.989976347064
# 1.0

# %% [markdown]
# ** Exercise #0.** Play with regularization parameter of RidgeRegression, see how it affects quality on train and test.
# Check quality of best model by submitting to kaggle.

# %%
ridgetest = []
for alpha in [0.01, 0.1, 1, 10, 100, 1000]:
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest.append([alpha,aa,bb,aa+bb])
    #print alpha, roc_auc_score(testY, ridge_clf.predict(testX)), roc_auc_score(trainY, ridge_clf.predict(trainX)) 
ridgetest
## alpha = 20
# Out:
# [[0.01, 1.0, 0.98390446521287633, 1.9839044652128763],
#  [0.1, 1.0, 0.98647167416637827, 1.9864716741663782],
#  [1, 1.0, 0.9899763470635744, 1.9899763470635743],
#  [10, 1.0, 0.99443290642667592, 1.9944329064266759],
#  [100, 0.99706121032588768, 0.9932935271720319, 1.9903547374979196],
#  [1000, 0.9762800272551958, 0.97902965270566522, 1.9553096799608611]]

# %%
ridgetest2 = []
for alpha in numpy.arange(20,30,1):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest2.append([alpha,aa,bb,aa+bb])
    #print alpha, roc_auc_score(testY, ridge_clf.predict(testX)), roc_auc_score(trainY, ridge_clf.predict(trainX)) 
ridgetest2
# Out:
# [[20, 0.99995300828319378, 0.99537037037037046, 1.9953233786535642],
#  [21, 0.99994035666713055, 0.9953992154147917, 1.9953395720819223],
#  [22, 0.99992409030362073, 0.99541363793700255, 1.9953377282406233],
#  [23, 0.99990240181894086, 0.99545690550363453, 1.9953593073225755],
#  [24, 0.9998879428291545, 0.99547132802584515, 1.9953592708549996],
#  [25, 0.99987348383936792, 0.99547132802584515, 1.9953448118652131],
#  [26, 0.99985721747585798, 0.99548575054805588, 1.9953429680239139],
#  [27, 0.99984275848607151, 0.99547132802584515, 1.9953140865119168],
#  [28, 0.99983733636490157, 0.9955001730702665, 1.995337509435168],
#  [29, 0.99981745525394505, 0.99551459559247724, 1.9953320508464223]]

# %%
ridge_clf = Ridge(alpha=24)
ridge_clf.fit(trainX, trainY)
create_solution(ridge_clf.predict(test_counts))
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %% [markdown]
# **Exercise #1.** Let's write the correspondence between columns and words (done below). Which words are most popular?

# %%
dictionary = numpy.empty(len(vectorizer.vocabulary_), dtype='O')
for word, index in vectorizer.vocabulary_.iteritems():
    dictionary[index] = word

# %%
# computing number of times each word met in the training dataset:
word_counts = counts.sum(axis=0)
print word_counts
# printing only words that occured more than 100 times
print dictionary[word_counts > 100]
# Out:
# [ 4 15  1 ...,  1  1  1]
# [u'all' u'am' u'and' u'are' u'at' u'be' u'but' u'by' u'call' u'can' u'come'
#  u'day' u'do' u'for' u'free' u'from' u'get' u'go' u'good' u'got' u'gt'
#  u'have' u'he' u'how' u'if' u'in' u'is' u'it' u'its' u'just' u'know'
#  u'like' u'll' u'love' u'lt' u'me' u'my' u'no' u'not' u'now' u'of' u'ok'
#  u'on' u'only' u'or' u'out' u'send' u'so' u'text' u'that' u'the' u'then'
#  u'there' u'this' u'time' u'to' u'up' u'ur' u'want' u'was' u'we' u'what'
#  u'when' u'will' u'with' u'you' u'your']

# %%
words_ordered_by_occurences = dictionary[numpy.argsort(word_counts)]
print words_ordered_by_occurences[-50:]
# Out:
# [u'free' u'day' u'good' u'out' u'll' u'go' u'ok' u'from' u'what' u'up'
#  u'all' u'when' u'how' u'this' u'gt' u'lt' u'no' u'with' u'or' u'ur' u'get'
#  u'just' u'will' u'be' u'we' u'if' u'at' u'but' u'not' u'do' u'so' u'can'
#  u'are' u'now' u'on' u'call' u'that' u'of' u'have' u'for' u'your' u'it'
#  u'my' u'me' u'in' u'is' u'and' u'the' u'you' u'to']

# %%
dist = numpy.sum(counts, axis=0)
#vocab = vectorizer.get_feature_names()
word_frq = []
for tag, count in zip(dictionary, dist):
    word_frq.append([count, tag])
    # print count, tag
word_frq.sort(reverse=True)
word_frq
# Out:
# [[1176, u'to'],
#  [1156, u'you'],
#  [715, u'the'],
#  [510, u'and'],
#  [483, u'is'],
#  [470, u'in'],
#  [427, u'me'],
#  [415, u'my'],
#  [391, u'it'],
#  [373, u'your'],
#  [368, u'for'],
#  [322, u'have'],
#  [321, u'of'],
#  [306, u'that'],
#  [296, u'call'],
#  [286, u'on'],
#  [278, u'now'],
#  [263, u'are'],
#  [260, u'can'],
#  [245, u'so'],
#  [229, u'not'],
#  [229, u'do'],
#  [227, u'but'],
#  [223, u'at'],
#  [220, u'if'],
#  [218, u'we'],
#  [215, u'be'],
#  [207, u'will'],
#  [206, u'just'],
#  [206, u'get'],
#  [205, u'ur'],
#  [203, u'with'],
#  [203, u'or'],
#  [202, u'no'],
#  [186, u'lt'],
#  [185, u'gt'],
#  [179, u'this'],
#  [168, u'how'],
#  [167, u'when'],
#  [164, u'all'],
#  [160, u'up'],
#  [159, u'what'],
#  [158, u'ok'],
#  [158, u'from'],
#  [157, u'go'],
#  [155, u'll'],
#  [149, u'out'],
#  [147, u'good'],
#  [143, u'day'],
#  [140, u'free'],
#  [136, u'come'],
#  [134, u'like'],
#  [134, u'know'],
#  [130, u'there'],
#  [126, u'its'],
#  [125, u'time'],
#  [125, u'then'],
#  [118, u'got'],
#  [116, u'was'],
#  [115, u'am'],
#  [109, u'only'],
#  [105, u'send'],
#  [104, u'love'],
#  [102, u'want'],
#  [102, u'he'],
#  [101, u'text'],
#  [101, u'by'],
#  [99, u'lor'],
#  [96, u'txt'],
#  [93, u'need'],
#  [93, u'as'],
#  [90, u'one'],
#  [90, u'going'],
#  [88, u'stop'],
#  [86, u'think'],
#  [86, u'home'],
#  [86, u'about'],
#  [83, u'still'],
#  [83, u'sorry'],
#  [83, u'see'],
#  [82, u'da'],
#  [81, u'take'],
#  [81, u'she'],
#  [80, u'they'],
#  [80, u'pls'],
#  [80, u'don'],
#  [78, u'back'],
#  [77, u'well'],
#  [77, u'tell'],
#  [77, u'been'],
#  [76, u'hi'],
#  [74, u'her'],
#  [73, u'today'],
#  [73, u'mobile'],
#  [71, u'week'],
#  [70, u're'],
#  [69, u'later'],
#  [69, u'here'],
#  [69, u'claim'],
#  [68, u'reply'],
#  [68, u'happy'],
#  [68, u'any'],
#  [67, u'night'],
#  [67, u'dont'],
#  [66, u'where'],
#  [66, u'please'],
#  [66, u'great'],
#  [65, u'who'],
#  [65, u'new'],
#  [65, u'did'],
#  [64, u'wat'],
#  [64, u'some'],
#  [64, u'our'],
#  [64, u'hope'],
#  [63, u'phone'],
#  [62, u'way'],
#  [62, u'him'],
#  [62, u'hey'],
#  [62, u'has'],
#  [62, u'dear'],
#  [62, u'an'],
#  [60, u'msg'],
#  [59, u'more'],
#  [59, u'give'],
#  [58, u'should'],
#  [58, u'oh'],
#  [57, u'www'],
#  [56, u'work'],
#  [56, u'im'],
#  [56, u'had'],
#  [55, u'prize'],
#  [55, u'make'],
#  [54, u'said'],
#  [54, u'right'],
#  [54, u'really'],
#  [54, u'message'],
#  [53, u'won'],
#  [53, u'doing'],
#  [53, u'after'],
#  [52, u'much'],
#  [51, u've'],
#  [51, u'tomorrow'],
#  [50, u'number'],
#  [47, u'yeah'],
#  [47, u'too'],
#  [47, u'ask'],
#  [47, u'anything'],
#  [46, u'cash'],
#  [45, u'meet'],
#  [45, u'let'],
#  [45, u'find'],
#  [44, u'say'],
#  [44, u'last'],
#  [43, u'morning'],
#  [43, u'care'],
#  [43, u'amp'],
#  [42, u'very'],
#  [42, u'thanks'],
#  [42, u'sure'],
#  [41, u'would'],
#  [41, u'win'],
#  [41, u'them'],
#  [41, u'lol'],
#  [41, u'com'],
#  [41, u'already'],
#  [41, u'150p'],
#  [40, u'yes'],
#  [40, u'uk'],
#  [40, u'something'],
#  [40, u'cant'],
#  [40, u'babe'],
#  [40, u'again'],
#  [39, u'every'],
#  [39, u'also'],
#  [38, u'why'],
#  [38, u'sent'],
#  [38, u'cos'],
#  [37, u'wait'],
#  [37, u'urgent'],
#  [37, u'around'],
#  [37, u'50'],
#  [36, u'life'],
#  [36, u'customer'],
#  [36, u'buy'],
#  [36, u'before'],
#  [35, u'which'],
#  [35, u'were'],
#  [35, u'went'],
#  [35, u'tonight'],
#  [35, u'over'],
#  [35, u'nice'],
#  [35, u'keep'],
#  [34, u'wish'],
#  [34, u'place'],
#  [34, u'help'],
#  [34, u'gonna'],
#  [34, u'contact'],
#  [34, u'always'],
#  [33, u'down'],
#  [32, u'tone'],
#  [32, u'someone'],
#  [32, u'pick'],
#  [32, u'other'],
#  [32, u'min'],
#  [32, u'chat'],
#  [32, u'bit'],
#  [32, u'18'],
#  [31, u'year'],
#  [31, u'wan'],
#  [31, u'us'],
#  [31, u'thing'],
#  [31, u'off'],
#  [31, u'nokia'],
#  [31, u'leave'],
#  [31, u'gud'],
#  [31, u'fine'],
#  [31, u'feel'],
#  [31, u'cool'],
#  [31, u'co'],
#  [30, u'yup'],
#  [30, u'sleep'],
#  [30, u'ready'],
#  [30, u'miss'],
#  [30, u'getting'],
#  [30, u'could'],
#  [30, u'16'],
#  [29, u'per'],
#  [29, u'next'],
#  [29, u'many'],
#  [29, u'house'],
#  [29, u'holiday'],
#  [29, u'heart'],
#  [29, u'god'],
#  [28, u'yet'],
#  [28, u'thk'],
#  [28, u'soon'],
#  [28, u'service'],
#  [28, u'haha'],
#  [28, u'guaranteed'],
#  [28, u'first'],
#  [28, u'dun'],
#  [27, u'waiting'],
#  [27, u'sms'],
#  [27, u'people'],
#  [27, u'may'],
#  [27, u'hello'],
#  [27, u'friends'],
#  [27, u'even'],
#  [27, u'coming'],
#  [27, u'better'],
#  [26, u'try'],
#  [26, u'told'],
#  [26, u'things'],
#  [26, u'talk'],
#  [26, u'stuff'],
#  [26, u'smile'],
#  [26, u'probably'],
#  [26, u'money'],
#  [26, u'long'],
#  [26, u'didn'],
#  [26, u'awarded'],
#  [25, u'thought'],
#  [25, u'sweet'],
#  [25, u'receive'],
#  [25, u'name'],
#  [25, u'man'],
#  [25, u'lunch'],
#  [25, u'lot'],
#  [25, u'line'],
#  [25, u'cs'],
#  [25, u'ah'],
#  [25, u'500'],
#  [24, u'wk'],
#  [24, u'than'],
#  [24, u'special'],
#  [24, u'nothing'],
#  [24, u'never'],
#  [24, u'meeting'],
#  [24, u'ever'],
#  [24, u'draw'],
#  [24, u'chance'],
#  [23, u'thats'],
#  [23, u'selected'],
#  [23, u'same'],
#  [23, u'mind'],
#  [23, u'late'],
#  [23, u'his'],
#  [23, u'having'],
#  [23, u'friend'],
#  [23, u'birthday'],
#  [23, u'100'],
#  [23, u'10'],
#  [22, u'sir'],
#  [22, u'shit'],
#  [22, u'live'],
#  [22, u'liao'],
#  [22, u'half'],
#  [22, u'end'],
#  [22, u'eat'],
#  [22, u'car'],
#  [22, u'award'],
#  [22, u'aight'],
#  [22, u'1000'],
#  [21, u'ya'],
#  [21, u'wanna'],
#  [21, u'sat'],
#  [21, u'person'],
#  [21, u'little'],
#  [21, u'ill'],
#  [21, u'guess'],
#  [21, u'finish'],
#  [21, u'den'],
#  [21, u'dat'],
#  [21, u'cost'],
#  [21, u'camera'],
#  [21, u'best'],
#  [21, u'because'],
#  [21, u'account'],
#  [21, u'1st'],
#  [20, u'world'],
#  [20, u'word'],
#  [20, u'wont'],
#  [20, u'weekend'],
#  [20, u'watch'],
#  [20, u'trying'],
#  [20, u'start'],
#  [20, u'school'],
#  [20, u'plan'],
#  [20, u'left'],
#  [20, u'guys'],
#  [20, u'enjoy'],
#  [20, u'does'],
#  [20, u'dinner'],
#  [20, u'days'],
#  [20, u'class'],
#  [20, u'baby'],
#  [19, u'while'],
#  [19, u'speak'],
#  [19, u'shows'],
#  [19, u'month'],
#  [19, u'minutes'],
#  [19, u'luv'],
#  [19, u'landline'],
#  [19, u'important'],
#  [19, u'hear'],
#  [19, u'done'],
#  [19, u'bt'],
#  [19, u'box'],
#  [19, u'being'],
#  [19, u'apply'],
#  [18, u'xxx'],
#  [18, u'thanx'],
#  [18, u'thank'],
#  [18, u'real'],
#  [18, u'quite'],
#  [18, u'problem'],
#  [18, u'princess'],
#  [18, u'po'],
#  [18, u'play'],
#  [18, u'lar'],
#  [18, u'into'],
#  [18, u'fun'],
#  [18, u'easy'],
#  [18, u'early'],
#  [18, u'details'],
#  [18, u'code'],
#  [18, u'check'],
#  [18, u'big'],
#  [18, u'another'],
#  [18, u'actually'],
#  [18, u'2nd'],
#  [18, u'150ppm'],
#  [17, u'yo'],
#  [17, u'without'],
#  [17, u'use'],
#  [17, u'tv'],
#  [17, u'says'],
#  [17, u'plz'],
#  [17, u'pay'],
#  [17, u'pa'],
#  [17, u'missing'],
#  [17, u'mins'],
#  [17, u'job'],
#  [17, u'hour'],
#  [17, u'forgot'],
#  [17, u'few'],
#  [17, u'evening'],
#  [17, u'dunno'],
#  [17, u'dreams'],
#  [16, u'wife'],
#  [16, u'town'],
#  [16, u'tmr'],
#  [16, u'times'],
#  [16, u'ringtone'],
#  [16, u'put'],
#  [16, u'okie'],
#  [16, u'okay'],
#  [16, u'office'],
#  [16, u'might'],
#  [16, u'messages'],
#  [16, u'maybe'],
#  [16, u'kiss'],
#  [16, u'feeling'],
#  [16, u'bus'],
#  [16, u'boy'],
#  [16, u'bad'],
#  [16, u'afternoon'],
#  [15, u'until'],
#  [15, u'true'],
#  [15, u'top'],
#  [15, u'room'],
#  [15, u'rite'],
#  [15, u'remember'],
#  [15, u'reach'],
#  [15, u'rate'],
#  [15, u'must'],
#  [15, u'movie'],
#  [15, u'most'],
#  [15, u'means'],
#  [15, u'latest'],
#  [15, u'juz'],
#  [15, u'hav'],
#  [15, u'guy'],
#  [15, u'gr8'],
#  [15, u'fuck'],
#  [15, u'food'],
#  [15, u'family'],
#  [15, u'driving'],
#  [15, u'dis'],
#  [15, u'dad'],
#  [15, u'coz'],
#  [15, u'collect'],
#  [15, u'between'],
#  [15, u'000'],
#  [14, u'years'],
#  [14, u'wot'],
#  [14, u'worry'],
#  [14, u'working'],
#  [14, u'valid'],
#  [14, u'those'],
#  [14, u'stay'],
#  [14, u'since'],
#  [14, u'shopping'],
#  [14, u'shop'],
#  [14, u'shall'],
#  [14, u'sexy'],
#  [14, u'orange'],
#  [14, u'once'],
#  [14, u'mob'],
#  [14, u'look'],
#  [14, u'jus'],
#  [14, u'hurt'],
#  [14, u'head'],
#  [14, u'haven'],
#  [14, u'girl'],
#  [14, u'gift'],
#  [14, u'friendship'],
#  [14, u'everything'],
#  [14, u'eve'],
#  [14, u'entry'],
#  [14, u'enough'],
#  [14, u'either'],
#  [14, u'decimal'],
#  [14, u'bring'],
#  [14, u'bored'],
#  [14, u'book'],
#  [14, u'bonus'],
#  [14, u'bed'],
#  [14, u'ard'],
#  [14, u'anyway'],
#  [14, u'alright'],
#  [14, u'abt'],
#  [14, u'250'],
#  [13, u'xmas'],
#  [13, u'weeks'],
#  [13, u'watching'],
#  [13, u'vouchers'],
#  [13, u'two'],
#  [13, u'todays'],
#  [13, u'til'],
#  [13, u'sad'],
#  [13, u'question'],
#  [13, u'pub'],
#  [13, u'pm'],
#  [13, u'oso'],
#  [13, u'online'],
#  [13, u'nite'],
#  [13, u'making'],
#  [13, u'http'],
#  [13, u'havent'],
#  [13, u'hard'],
#  [13, u'goin'],
#  [13, u'games'],
#  [13, u'drive'],
#  [13, u'colour'],
#  [13, u'collection'],
#  [13, u'club'],
#  [13, u'change'],
#  [13, u'calls'],
#  [13, u'called'],
#  [13, u'beautiful'],
#  [13, u'asked'],
#  [13, u'answer'],
#  [13, u'address'],
#  [13, u'350'],
#  [13, u'2000'],
#  [12, u'words'],
#  [12, u'wid'],
#  [12, u'whats'],
#  [12, u'wants'],
#  [12, u'update'],
#  [12, u'tones'],
#  [12, u'till'],
#  [12, u'texts'],
#  [12, u'test'],
#  [12, u'started'],
#  [12, u'sleeping'],
#  [12, u'set'],
#  [12, u'saying'],
#  [12, u'private'],
#  [12, u'pounds'],
#  [12, u'plus'],
#  [12, u'pics'],
#  [12, u'part'],
#  [12, u'pain'],
#  [12, u'national'],
#  [12, u'music'],
#  [12, u'missed'],
#  [12, u'mate'],
#  [12, u'made'],
#  [12, u'lose'],
#  [12, u'looking'],
#  [12, u'lei'],
#  [12, u'info'],
#  [12, u'id'],
#  [12, u'hungry'],
#  [12, u'hot'],
#  [12, u'hair'],
#  [12, u'haf'],
#  [12, u'full'],
#  [12, u'fri'],
#  [12, u'email'],
#  [12, u'dude'],
#  [12, u'college'],
#  [12, u'chikku'],
#  [12, u'awesome'],
#  [12, u'attempt'],
#  [12, u'angry'],
#  [12, u'8007'],
#  [12, u'800'],
#  [12, u'10p'],
#  [11, u'yesterday'],
#  [11, u'winner'],
#  [11, u'wif'],
#  [11, u'wen'],
#  [11, u'weekly'],
#  [11, u'voucher'],
#  [11, u'video'],
#  [11, u'valued'],
#  [11, u'trip'],
#  [11, u'treat'],
#  [11, u'tot'],
#  [11, u'thinking'],
#  [11, u'story'],
#  [11, u'statement'],
#  [11, u'sounds'],
#  [11, u'snow'],
#  [11, u'smiling'],
#  [11, u'show'],
#  [11, u'services'],
#  [11, u'search'],
#  [11, u'sae'],
#  [11, u'row'],
#  [11, u'post'],
#  [11, u'points'],
#  [11, u'pic'],
#  [11, u'order'],
#  [11, u'offer'],
#  [11, u'noe'],
#  [11, u'neva'],
#  [11, u'makes'],
#  [11, u'leh'],
#  [11, u'leaving'],
#  [11, u'least'],
#  [11, u'join'],
#  [11, u'hours'],
#  [11, u'goes'],
#  [11, u'girls'],
#  [11, u'friday'],
#  [11, u'finished'],
#  [11, u'each'],
#  [11, u'didnt'],
#  [11, u'date'],
#  [11, u'congratulations'],
#  [11, u'calling'],
#  [11, u'brother'],
#  [11, u'believe'],
#  [11, u'await'],
#  [11, u'able'],
#  [11, u'86688'],
#  [11, u'150'],
#  [11, u'11'],
#  [10, u'xx'],
#  [10, u'wil'],
#  [10, u'welcome'],
#  [10, u'wana'],
#  [10, u'wake'],
#  [10, u'used'],
#  [10, u'touch'],
#  [10, u'though'],
#  [10, u'these'],
#  [10, u'sis'],
#  [10, u'saw'],
#  [10, u'rs'],
#  [10, u'price'],
#  [10, u'player'],
#  [10, u'parents'],
#  [10, u'network'],
#  [10, u'net'],
#  [10, u'minute'],
#  [10, u'mean'],
#  [10, u'mail'],
#  [10, u'ltd'],
#  [10, u'listen'],
#  [10, u'lesson'],
#  [10, u'land'],
#  [10, u'happiness'],
#  [10, u'expires'],
#  [10, u'else'],
#  [10, u'drop'],
#  [10, u'delivery'],
#  [10, u'decided'],
#  [10, u'de'],
#  [10, u'cum'],
#  [10, u'company'],
#  [10, u'comes'],
#  [10, u'choose'],
#  [10, u'charge'],
#  [10, u'cause'],
#  [10, u'carlos'],
#  [10, u'came'],
#  [10, u'break'],
#  [10, u'bout'],
#  [10, u'both'],
#  [10, u'away'],
#  [10, u'ass'],
#  [10, u'ago'],
#  [10, u'aft'],
#  [10, u'5000'],
#  [9, u'worth'],
#  [9, u'wkly'],
#  [9, u'within'],
#  [9, u'whole'],
#  [9, u'walk'],
#  [9, u'took'],
#  [9, u'tho'],
#  [9, u'th'],
#  [9, u'sun'],
#  [9, u'st'],
#  [9, u'smoke'],
#  [9, u'remove'],
#  [9, u'reason'],
#  [9, u'party'],
#  [9, u'outside'],
#  [9, u'opt'],
#  [9, u'old'],
#  [9, u'msgs'],
#  [9, u'mayb'],
#  [9, u'march'],
#  [9, u'lovely'],
#  [9, u'lost'],
#  [9, u'lets'],
#  [9, u'ipod'],
#  [9, u'il'],
#  [9, u'identifier'],
#  [9, u'hmv'],
#  [9, u'happened'],
#  [9, u'happen'],
#  [9, u'gas'],
#  [9, u'freemsg'],
#  [9, u'fancy'],
#  [9, u'face'],
#  [9, u'everyone'],
#  [9, u'drink'],
#  [9, u'dnt'],
#  [9, u'convey'],
#  [9, u'congrats'],
#  [9, u'chennai'],
#  [9, u'brings'],
#  [9, u'anyone'],
#  [9, u'12hrs'],
#  [8, u'yourself'],
#  [8, u'yours'],
#  [8, u'yar'],
#  [8, u'wow'],
#  [8, u'wonderful'],
#  [8, u'wishing'],
#  [8, u'wasn'],
#  [8, u'wanted'],
#  [8, u'unsubscribe'],
#  [8, u'type'],
#  [8, u'through'],
#  [8, u'ten'],
#  [8, u'tel'],
#  [8, u'takes'],
#  [8, u'swing'],
#  [8, u'surprise'],
#  [8, u'supposed'],
#  [8, u'support'],
#  [8, u'suite342'],
#  [8, u'somewhere'],
#  [8, u'slow'],
#  [8, u'second'],
#  [8, u'safe'],
#  [8, u'run'],
#  [8, u'red'],
#  [8, u'promise'],
#  [8, u'prob'],
#  [8, u'pretty'],
#  [8, u'press'],
#  [8, u'poly'],
#  [8, u'point'],
#  [8, u'park'],
#  [8, u'orchard'],
#  [8, u'numbers'],
#  [8, u'nt'],
#  [8, u'mu'],
#  [8, u'mom'],
#  [8, u'mates'],
#  [8, u'mah'],
#  [8, u'lucky'],
#  [8, u'loving'],
#  [8, u'lots'],
#  [8, u'loads'],
#  [8, u'kind'],
#  [8, u'invited'],
#  [8, u'huh'],
#  [8, u'hows'],
#  [8, u'hold'],
#  [8, u'hmmm'],
#  [8, u'hit'],
#  [8, u'heard'],
#  [8, u'grins'],
#  [8, u'gone'],
#  [8, u'glad'],
#  [8, u'found'],
#  [8, u'final'],
#  [8, u'felt'],
#  [8, u'empty'],
#  [8, u'earlier'],
#  [8, u'doesn'],
#  [8, u'difficult'],
#  [8, u'currently'],
#  [8, u'credit'],
#  [8, u'couple'],
#  [8, u'complimentary'],
#  [8, u'close'],
#  [8, u'christmas'],
#  [8, u'charged'],
#  [8, u'callertune'],
#  [8, u'busy'],
#  [8, u'bill'],
#  [8, u'bath'],
#  [8, u'balance'],
#  [8, u'askd'],
#  [8, u'alone'],
#  [8, u'87066'],
#  [8, u'750'],
#  [8, u'30'],
#  [8, u'2lands'],
#  [8, u'2003'],
#  [8, u'04'],
#  [7, u'yr'],
#  [7, u'wishes'],
#  [7, u'whatever'],
#  [7, u'wap'],
#  [7, u'via'],
#  [7, u'un'],
#  [7, u'ts'],
#  [7, u'truth'],
#  [7, u'tomo'],
#  [7, u'together'],
#  [7, u'tired'],
#  [7, u'thinks'],
#  [7, u'thinkin'],
#  [7, u'their'],
#  [7, u'terms'],
#  [7, u'telling'],
#  [7, u'tampa'],
#  [7, u'talking'],
#  [7, u'swt'],
#  [7, u'std'],
#  [7, u'specially'],
#  [7, u'sort'],
#  [7, u'somebody'],
#  [7, u'slowly'],
#  [7, u'side'],
#  [7, u'sex'],
#  [7, u'semester'],
#  [7, u'seen'],
#  [7, u'secret'],
#  [7, u'sea'],
#  [7, u'rest'],
#  [7, u'redeemed'],
#  [7, u'reading'],
#  [7, u'read'],
#  [7, u'pobox'],
#  [7, u'pix'],
#  [7, u'pass'],
#  [7, u'paper'],
#  [7, u'others'],
#  [7, u'oredi'],
#  [7, u'operator'],
#  [7, u'open'],
#  [7, u'ni8'],
#  [7, u'news'],
#  [7, u'mum'],
#  [7, u'mrt'],
#  [7, u'monday'],
#  [7, u'mine'],
#  [7, u'match'],
#  [7, u'luck'],
#  [7, u'lovable'],
#  [7, u'log'],
#  [7, u'lemme'],
#  [7, u'ive'],
#  [7, u'insurance'],
#  [7, u'ice'],
#  [7, u'hospital'],
#  [7, u'hoping'],
#  [7, u'hand'],
#  [7, u'ha'],
#  [7, u'gotta'],
#  [7, u'goodmorning'],
#  [7, u'gettin'],
#  [7, u'gd'],
#  [7, u'fucking'],
#  [7, u'frnds'],
#  [7, u'frm'],
#  [7, u'forget'],
#  [7, u'finally'],
#  [7, u'fantastic'],
#  [7, u'ex'],
#  [7, u'especially'],
#  [7, u'ending'],
#  [7, u'eg'],
#  [7, u'download'],
#  [7, u'doin'],
#  [7, u'dead'],
#  [7, u'dating'],
#  [7, u'darlin'],
#  [7, u'copy'],
#  [7, u'confirm'],
#  [7, u'computer'],
#  [7, u'comp'],
#  [7, u'caller'],
#  [7, u'bslvyl'],
#  [7, u'boytoy'],
#  [7, u'booked'],
#  [7, u'blue'],
#  [7, u'bcoz'],
#  [7, u'bb'],
#  [7, u'bathe'],
#  [7, u'bank'],
#  [7, u'bak'],
#  [7, u'area'],
#  [7, u'age'],
#  [7, u'0800'],
#  [6, u'yrs'],
#  [6, u'worried'],
#  [6, u'wit'],
#  [6, u'whenever'],
#  [6, u'warm'],
#  [6, u'w1j6hl'],
#  [6, u'vodafone'],
#  [6, u'vl'],
#  [6, u'visit'],
#  [6, u'valentines'],
#  [6, u'usual'],
#  [6, u'using'],
#  [6, u'usf'],
#  [6, u'urself'],
#  [6, u'tried'],
#  [6, u'tickets'],
#  [6, u'tea'],
#  [6, u'taking'],
#  [6, u'study'],
#  [6, u'straight'],
#  [6, u'starting'],
#  [6, u'south'],
#  [6, u'sofa'],
#  [6, u'smth'],
#  [6, u'slave'],
#  [6, u'sitting'],
#  [6, u'sister'],
#  [6, u'sick'],
#  [6, u'serious'],
#  [6, u'sending'],
#  [6, u'sch'],
#  [6, u'rock'],
#  [6, u'ring'],
#  [6, u'reveal'],
#  [6, u'request'],
#  [6, u'rental'],
#  [6, u'reference'],
#  [6, u'rather'],
#  [6, u'quiz'],
#  [6, u'questions'],
#  [6, u'plans'],
#  [6, u'persons'],
#  [6, u'paying'],
#  [6, u'own'],
#  [6, u'opinion'],
#  [6, u'ones'],
#  [6, u'o2'],
#  [6, u'nope'],
#  [6, u'nimya'],
#  [6, u'nah'],
#  [6, u'myself'],
#  [6, u'mp3'],
#  [6, u'move'],
#  [6, u'months'],
#  [6, u'mm'],
#  [6, u'met'],
#  [6, u'merry'],
#  [6, u'medical'],
#  [6, u'meant'],
#  [6, u'matches'],
#  [6, u'loved'],
#  [6, u'longer'],
#  [6, u'london'],
#  [6, u'loan'],
#  [6, u'lmao'],
#  [6, u'liked'],
#  [6, u'light'],
#  [6, u'la'],
#  [6, u'knows'],
#  [6, u'kinda'],
#  [6, u'jay'],
#  [6, u'isn'],
#  [6, u'inc'],
#  [6, u'honey'],
#  [6, u'hmm'],
#  [6, u'hiya'],
#  [6, u'hg'],
#  [6, u'gn'],
#  [6, u'ge'],
#  [6, u'game'],
#  [6, u'future'],
#  [6, u'fullonsms'],
#  [6, u'forwarded'],
#  [6, u'flower'],
#  [6, u'flirt'],
#  [6, u'feels'],
#  [6, u'fat'],
#  [6, u'fast'],
#  [6, u'etc'],
#  [6, u'entered'],
#  [6, u'england'],
#  [6, u'due'],
#  [6, u'double'],
#  [6, u'doesnt'],
#  [6, u'discount'],
#  [6, u'digital'],
#  [6, u'del'],
#  [6, u'deep'],
#  [6, u'decide'],
#  [6, u'cuz'],
#  [6, u'custcare'],
#  [6, u'crazy'],
#  [6, u'contract'],
#  [6, u'content'],
#  [6, u'comin'],
#  [6, u'colleagues'],
#  [6, u'coffee'],
#  [6, u'cine'],
#  [6, u'changed'],
#  [6, u'card'],
#  [6, u'cancel'],
#  [6, u'bother'],
#  [6, u'blood'],
#  [6, u'battery'],
#  [6, u'b4'],
#  [6, u'awaiting'],
#  [6, u'apartment'],
#  [6, u'anytime'],
#  [6, u'almost'],
#  [6, u'advance'],
#  [6, u'across'],
#  [6, u'abiola'],
#  [6, u'900'],
#  [6, u'87077'],
#  [6, u'50p'],
#  [6, u'4u'],
#  [6, u'20'],
#  [6, u'12'],
#  [6, u'11mths'],
#  [5, u'yep'],
#  [5, u'xy'],
#  [5, u'wrong'],
#  ...]

# %% [markdown]
# ** Exercise #2. ** By analyzing coefficients in `ridge_clf.coef_`, determine which words have the highest impact on decision (= have the largest modulus of `coef_`)

# %%
par_impact=zip(dictionary, ridge_clf.coef_)
par_impact_new=sorted(par_impact, key=lambda x: abs(x[1]), reverse=True)

# %%
par_impact_new
# Out:
# [(u'txt', 0.15285770050925185),
#  (u'call', 0.14383880743023994),
#  (u'uk', 0.13937018195586354),
#  (u'claim', 0.13383817103372986),
#  (u'150p', 0.12353058171563081),
#  (u'text', 0.12295954893969727),
#  (u'service', 0.12164892024913812),
#  (u'www', 0.11721507473858522),
#  (u'mobile', 0.10871430758407745),
#  (u'50', 0.10644871323134385),
#  (u'win', 0.10459491583878276),
#  (u'reply', 0.10128167797023323),
#  (u'won', 0.093737417953707075),
#  (u'com', 0.092384004362587854),
#  (u'chat', 0.091588166275559629),
#  (u'free', 0.090999968625093852),
#  (u'customer', 0.089053324721986321),
#  (u'ringtone', 0.088830139016501122),
#  (u'urgent', 0.083949646478080189),
#  (u'stop', 0.083931502140508249),
#  (u'88066', 0.079688296076504433),
#  (u'awarded', 0.079500482005874562),
#  (u'18', 0.079494881727091779),
#  (u'prize', 0.07859191579270057),
#  (u'or', 0.078184184673863011),
#  (u'camera', 0.077228174334375246),
#  (u'http', 0.076033905206554037),
#  (u'new', 0.075394553927519981),
#  (u'ltd', 0.073522346401953959),
#  (u'from', 0.073365516384588714),
#  (u'500', 0.072344633489521318),
#  (u'receive', 0.071091351989152229),
#  (u'cost', 0.067332784734551121),
#  (u'private', 0.066644877988817117),
#  (u'your', 0.066322001150048687),
#  (u'help', 0.065865278919909939),
#  (u'games', 0.065632146688914372),
#  (u'who', 0.064849764898411891),
#  (u'important', 0.063015280325478512),
#  (u'co', 0.061838020998733735),
#  (u'sexy', 0.06177673599365132),
#  (u'fancy', 0.061193817218860483),
#  (u'delivery', 0.060382407762214305),
#  (u'selected', 0.05972939699313843),
#  (u'minmobsmorelkpobox177hp51fl', 0.059664462181737453),
#  (u'statement', 0.059654278372024402),
#  (u'apply', 0.059061227049150615),
#  (u'dating', 0.059051491522325056),
#  (u'po', 0.058807619233076994),
#  (u'msg', 0.058002111744808738),
#  (u'arsenal', 0.057823519749589894),
#  (u'code', 0.057592497087868587),
#  (u'message', 0.057337381694091284),
#  (u'holiday', 0.056632957303974302),
#  (u'min', 0.056385755761771128),
#  (u'tones', 0.056252825799878781),
#  (u'announcement', 0.056184023487144595),
#  (u'special', 0.055721060544783249),
#  (u'cash', 0.055604163883734195),
#  (u'tone', 0.055218989601733187),
#  (u'club', 0.054242419399337966),
#  (u'2003', 0.054147394814042932),
#  (u'bid', 0.053928535402744116),
#  (u'with', 0.053928098681157804),
#  (u'pics', 0.05377634876729017),
#  (u'draw', 0.053333908467562086),
#  (u'100', 0.052845542386210101),
#  (u'attempt', 0.052211949158977519),
#  (u'xxx', 0.052003630131140711),
#  (u'rate', 0.051673195713479933),
#  (u'wap', 0.051135762356448261),
#  (u'mob', 0.049595489003594569),
#  (u'collection', 0.049468940139699921),
#  (u'800', 0.049331027245807117),
#  (u'now', 0.049265420174800005),
#  (u'info', 0.048857783554289345),
#  (u'1000', 0.04852844549616861),
#  (u'landline', 0.048249616857709551),
#  (u'lose', -0.047434646140784999),
#  (u'weekly', 0.047382517593356308),
#  (u'contact', 0.046993615217571734),
#  (u'hot', 0.046678151608511464),
#  (u'calls', 0.046671171638308015),
#  (u'250', 0.046465692333030051),
#  (u'top', 0.045844846278201401),
#  (u'std', 0.044714510461161899),
#  (u'lucy', 0.044323309607261635),
#  (u'box', 0.044319274315062836),
#  (u'ring', 0.044228824543212704),
#  (u'sale', 0.043040686838321941),
#  (u'find', 0.042558383509067599),
#  (u'every', 0.042442751878988091),
#  (u'user', 0.042392513411067451),
#  (u'later', -0.042233739797282156),
#  (u'winner', 0.042148681875267581),
#  (u'per', 0.042009185251762421),
#  (u'fullonsms', -0.04192335822499875),
#  (u'live', 0.041885958658494205),
#  (u'vodafone', 0.041468684040838567),
#  (u'an', 0.040639741690811346),
#  (u'word', 0.040634105135686882),
#  (u'tv', 0.040396142015515606),
#  (u'luck', 0.040209270301589162),
#  (u'true', 0.039861012189876137),
#  (u'collect', 0.039816967498365996),
#  (u'award', 0.039780952048894314),
#  (u'our', 0.039685183644727652),
#  (u'line', 0.039582723487798364),
#  (u'sky', 0.039421863343502964),
#  (u'expires', 0.039061775253693191),
#  (u'choose', 0.038907405900464029),
#  (u'lost', 0.038846792987690108),
#  (u'amp', -0.038598206791915848),
#  (u'play', 0.038397405597981951),
#  (u'please', 0.038161300269842928),
#  (u'slo', 0.038067152058580286),
#  (u'they', 0.037854105996512386),
#  (u'term', 0.037812497063321376),
#  (u'chance', 0.037525916430184804),
#  (u'went', -0.01398914785898356),
#  (u'8552', 0.013981199233585531),
#  (u'things', 0.013976237369022296),
#  (u'69988', 0.01394389398310582),
#  (u'rcv', 0.01394389398310582),
#  (u'svc', 0.01394389398310582),
#  (u'verify', 0.01394389398310582),
#  (u'selling', 0.013942766773265261),
#  (u'include', 0.013913066073477875),
#  (u'don', -0.01390143561912263),
#  (u'net', 0.013886030433958269),
#  (u'easy', 0.013873784668376696),
#  (u'09061209465', 0.013855834741889476),
#  (u'150pm', 0.013855834741889476),
#  (u'matrix3', 0.013855834741889476),
#  (u'starwars3', 0.013855834741889476),
#  (u'suprman', 0.013855834741889476),
#  (u'rcvd', 0.013853804587968709),
#  (u'sam', 0.013810544846423802),
#  (u'hav', -0.013715771706523213),
#  (u'gt', -0.013676125017650753),
#  (u'doin', -0.013664765660957791),
#  (u'15541', 0.013656557893391172),
#  (u'450', 0.013656557893391172),
#  (u'62735', 0.013656557893391172),
#  (u'83039', 0.013656557893391172),
#  (u'accommodationvouchers', 0.013656557893391172),
#  (u'mustprovide', 0.013656557893391172),
#  (u'ph', 0.013606188093276846),
#  (u'rock', -0.013604263104755024),
#  (u'answer', 0.013582699784881651),
#  (u'infront', -0.013575653060899636),
#  (u'came', 0.013536944244094774),
#  (u'goodmorning', -0.01350742731075022),
#  (u'india', 0.01349023984197196),
#  (u'71', 0.013482133850686029),
#  (u'83383', 0.013482133850686029),
#  (u'bids', 0.013482133850686029),
#  (u'highest', 0.013482133850686029),
#  (u'maximum', 0.013482133850686029),
#  (u'algarve', 0.013472896127436023),
#  (u'ansr', 0.013472896127436023),
#  (u'dvd', 0.013472896127436023),
#  (u'sony', 0.013472896127436023),
#  (u'tyrone', 0.013472896127436023),
#  (u'booking', 0.013337954378347746),
#  (u'10p', 0.013317564192576252),
#  (u'lot', -0.01330851241646352),
#  (u'30', 0.013302284800925202),
#  (u'british', 0.013250034434502614),
#  (u'hotels', 0.013250034434502614),
#  (u'sw73ss', 0.013250034434502614),
#  (u'doing', -0.013234248582166781),
#  (u'match', 0.013169360124210374),
#  (u'talking', -0.013163512870724718),
#  (u'safe', -0.013129703738096405),
#  (u'saturday', 0.013123388000096698),
#  (u'bahamas', 0.013040821547737476),
#  (u'month', -0.01304011172582592),
#  (u'pls', -0.013014297541586724),
#  (u'250k', 0.013005957961061448),
#  (u'88088', 0.013005957961061448),
#  (u'active', 0.013005957961061448),
#  (u'gamestar', 0.013005957961061448),
#  (u'scoring', 0.013005957961061448),
#  (u'88888', 0.012973657972080808),
#  (u'here', -0.01293440364442692),
#  (u'flag', 0.012852548162918285),
#  (u'mode', -0.012802952914161786),
#  (u'records', 0.01275074114145894),
#  (u'lounge', 0.01271343867811524),
#  (u'mp3', 0.012705632414543063),
#  (u'we', -0.012558452733831235),
#  (u'black', 0.012557678682651261),
#  (u'saying', -0.012557175966309796),
#  (u'support', -0.012525472150741325),
#  (u'couple', -0.012517962711252618),
#  (u'texts', -0.012429154490236925),
#  (u'11mths', 0.012407737221677097),
#  (u'inc', 0.012378219809384061),
#  (u'insurance', 0.012365833220546501),
#  (u'ex', -0.01235591483693566),
#  (u'ah', -0.012341207467845517),
#  (u'hasnt', -0.01232988152030022),
#  (u'questions', 0.012322964880202909),
#  (u'school', -0.012311718319614031),
#  (u'dot', 0.012189652234356261),
#  (u'found', 0.012180835679985416),
#  (u'closer', -0.01217367191450024),
#  (u'dear', -0.012099985579036266),
#  (u'08712402050', 0.012080580794186759),
#  (u'10ppm', 0.012080580794186759),
#  (u'ag', 0.012080580794186759),
#  (u'lines', 0.012080580794186759),
#  (u'promo', 0.012080580794186759),
#  (u'thanks', 0.012072633381158267),
#  (u'anyway', -0.012043693054812064),
#  (u'da', -0.011992631806393405),
#  (u'dead', -0.011962134908535264),
#  (u'tncs', 0.011909782870306631),
#  (u'arrange', 0.011892494605009419),
#  (u'21', 0.011883306368397425),
#  (u'remove', -0.011882476723372911),
#  (u'mom', -0.011879812110494605),
#  (u'07', 0.011868874122574452),
#  (u'41685', 0.011868874122574452),
#  (u'flirt', 0.01186218361520185),
#  (u'anna', -0.011812084984650514),
#  (u'nagar', -0.011812084984650514),
#  (u'thought', -0.011798865648011822),
#  (u'dificult', -0.011796661384343512),
#  (u'fightng', -0.011796661384343512),
#  (u'dogging', 0.011792953388874362),
#  (u'grins', -0.011788115871671482),
#  (u'calling', -0.011785328976637591),
#  (u'2006', 0.011785245339900663),
#  (u'fifa', 0.011785245339900663),
#  (u'held', 0.011785245339900663),
#  (u'back', 0.011780792593332),
#  (u'mobiles', 0.011765111122880246),
#  (u'available', -0.01174512729410602),
#  (u'soon', -0.011740478145938192),
#  (u'type', -0.011736165440512914),
#  (u'change', -0.011729800378366812),
#  (u'didn', -0.011726485607222923),
#  (u'sending', -0.011708169898799629),
#  (u'make', 0.011706382201465864),
#  (u'colour', -0.011696255882298405),
#  (u'ideas', -0.011685555160858587),
#  (u'88877', 0.011634373560658558),
#  (u'getting', -0.011631978092884295),
#  (u'game', 0.01161260918731986),
#  (u'wiv', 0.011607163257198896),
#  (u'chennai', -0.01158234600153237),
#  (u'caller', 0.011580572759082586),
#  (u'thread', -0.011564135345102188),
#  (u'wake', -0.011542113827171806),
#  (u'cute', 0.01153919479585017),
#  (u'afternoon', -0.011504257707399762),
#  (u'country', 0.011500640879285207),
#  (u'isnt', -0.011472974879008717),
#  (u'happiness', -0.011464402265650795),
#  (u'sister', -0.011462104724952132),
#  (u'lovable', -0.011395839273880673),
#  (u'40gb', 0.011369521574061616),
#  (u'promise', -0.011358422396075964),
#  (u'want', -0.011349319647730645),
#  (u'halloween', 0.011327220762823716),
#  (u'logo', 0.011327220762823716),
#  (u'spook', 0.011327220762823716),
#  (u'sppok', 0.011327220762823716),
#  (u'ever', 0.011317053671700592),
#  (u'well', -0.011311317502015104),
#  (u'total', 0.011304276466079469),
#  (u'24', 0.011273931757734225),
#  (u'08702840625', 0.011270935531078743),
#  (u'220', 0.011270935531078743),
#  (u'3qxj9', 0.011270935531078743),
#  (u'log', 0.010550908965709302),
#  (u'complimentary', 0.010547577272328201),
#  (u'up', -0.010543422248256679),
#  (u'of', 0.010537693163210239),
#  (u'blue', -0.010534749485489221),
#  (u'fine', -0.010510581962061808),
#  (u'loyalty', 0.010499287266656207),
#  (u'09056242159', 0.010492080504219108),
#  (u'21870000', 0.010492080504219108),
#  (u'alert', 0.010492080504219108),
#  (u'mailbox', 0.010492080504219108),
#  (u'messaging', 0.010492080504219108),
#  (u'retrieve', 0.010492080504219108),
#  (u'sms', 0.010454391826292217),
#  (u'sweet', -0.010428398990148597),
#  ...]

# %% [markdown]
# ** Exercise #3. **  Does combining features and counts improve quality? Use `numpy.hstack` to concatenate arrays.
# Explain the result.

# %%
counts.shape, features.shape, numpy.hstack((counts,features)).shape

combined = numpy.hstack((counts,features))
trainX, testX, trainY, testY = train_test_split(combined, answers, random_state=42)

ridgetest = []
for alpha in [0.01, 0.1, 1, 10, 100, 1000]:
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest.append([alpha,aa,bb,aa+bb])
ridgetest
# Out:
# [[0.01, 1.0, 0.9905388254297911, 1.9905388254297911],
#  [0.1, 1.0, 0.9914041767624322, 1.9914041767624322],
#  [1, 1.0, 0.99190896503980608, 1.9919089650398061],
#  [10, 1.0, 0.99519730010384211, 1.9951973001038421],
#  [100, 0.99893907162441331, 0.99714434060228452, 1.9960834122266977],
#  [1000, 0.99123062269446893, 0.99610591900311518, 1.9873365416975841]]

# %%
ridgetest2 = []
for alpha in numpy.arange(10,100,10):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest2.append([alpha,aa,bb,aa+bb])
ridgetest2
# Out:
# [[10, 1.0, 0.99920676127841235, 1.9992067612784123],
#  [20, 0.99999277050510671, 0.99927887388946568, 1.9992716443945724],
#  [30, 0.99995662303064037, 0.99925002884504444, 1.9992066518756848],
#  [40, 0.99988252070798445, 0.99922118380062308, 1.9991037045086075],
#  [50, 0.99977588565830877, 0.99910580362293755, 1.9988816892812462],
#  [60, 0.99964575475022999, 0.99906253605630546, 1.9987082908065354],
#  [70, 0.99949032061002474, 0.99901926848967348, 1.9985095890996982],
#  [80, 0.99932584960120296, 0.99899042344525202, 1.998316273046455],
#  [90, 0.99917764495589112, 0.99899042344525213, 1.9981680684011431]]

# %%
ridgetest3 = []
for alpha in numpy.arange(10,20,1):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest3.append([alpha,aa,bb,aa+bb])
ridgetest3
# Out:
# [[10, 1.0, 0.99920676127841235, 1.9992067612784123],
#  [11, 1.0, 0.99927887388946579, 1.9992788738894658],
#  [12, 1.0, 0.99927887388946579, 1.9992788738894658],
#  [13, 1.0, 0.99929329641167652, 1.9992932964116765],
#  [14, 1.0, 0.99930771893388715, 1.999307718933887],
#  [15, 0.99999999999999989, 0.99929329641167641, 1.9992932964116763],
#  [16, 0.99999999999999989, 0.99929329641167652, 1.9992932964116763],
#  [17, 0.99999638525255341, 0.99929329641167652, 1.99928968166423],
#  [18, 0.99999638525255341, 0.99929329641167641, 1.9992896816642298],
#  [19, 0.99999457787883017, 0.99927887388946579, 1.999273451768296]]

# %%
ridgetest4 = []
for alpha in numpy.arange(14,15,0.1):
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest4.append([alpha,aa,bb,aa+bb])
ridgetest4
# Out:
# [[14.0, 1.0, 0.99930771893388715, 1.999307718933887],
#  [14.1, 1.0, 0.99930771893388715, 1.999307718933887],
#  [14.199999999999999, 1.0, 0.99929329641167652, 1.9992932964116765],
#  [14.299999999999999, 1.0, 0.99929329641167652, 1.9992932964116765],
#  [14.399999999999999, 1.0, 0.99929329641167652, 1.9992932964116765],
#  [14.499999999999998, 1.0, 0.99929329641167641, 1.9992932964116763],
#  [14.599999999999998, 1.0, 0.99929329641167641, 1.9992932964116763],
#  [14.699999999999998, 1.0, 0.99929329641167641, 1.9992932964116763],
#  [14.799999999999997, 1.0, 0.99929329641167641, 1.9992932964116763],
#  [14.899999999999997, 1.0, 0.99929329641167641, 1.9992932964116763]]

# %%
sorted(ridgetest4,key=lambda x: x[3])
# Out:
# [[43.300000000000004,
#   0.99981745525394516,
#   0.99701453790238836,
#   1.9968319931563334],
#  [43.200000000000003,
#   0.9998192626276684,
#   0.99701453790238836,
#   1.9968338005300568],
#  [43.900000000000013,
#   0.99980841838532841,
#   0.9970289604245991,
#   1.9968373788099276],
#  [43.0, 0.99982287737511499, 0.99701453790238836, 1.9968374152775032],
#  [43.100000000000001,
#   0.99982287737511499,
#   0.99701453790238836,
#   1.9968374152775032],
#  [43.400000000000006,
#   0.99981564788022181,
#   0.99702896042459899,
#   1.9968446083048208],
#  [43.800000000000011,
#   0.99981022575905176,
#   0.99704338294680983,
#   1.9968536087058615],
#  [43.600000000000009,
#   0.99981384050649846,
#   0.99704338294680972,
#   1.9968572234533082],
#  [43.70000000000001,
#   0.99981384050649846,
#   0.99704338294680983,
#   1.9968572234533082],
#  [43.500000000000007,
#   0.99981564788022181,
#   0.99704338294680972,
#   1.9968590308270315]]

# %%
#combined_test = numpy.hstack((test_counts,kaggle_test_features))
#combined_train = numpy.hstack((counts,features))

ridge_clf = Ridge(alpha=14)
ridge_clf.fit(trainX, trainY)
create_solution(ridge_clf.predict(combined_test))
# Out:
# C:\Users\Yanjie\OneDrive\Documents\01-Work\08-Courses\MLatImperial2016\data\1-sms-spam-predictions.csv

# %%
## trying to improve

# %%
vectorizer = CountVectorizer(token_pattern='\\b\\w+\\b')  
vectorizer.fit(messages)
counts = vectorizer.transform(messages).toarray()
test_counts = vectorizer.transform(kaggle_test_messages).toarray()
vectorizer.fit_transform(messages)
vocab = vectorizer.get_feature_names()
combined = numpy.hstack((counts,features))
trainX, testX, trainY, testY = train_test_split(combined, answers, random_state=42)

# %%
ridgetest = []
for alpha in [0.01, 0.1, 1, 10, 100, 1000]:
    ridge_clf = Ridge(alpha)
    ridge_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, ridge_clf.predict(trainX))
    bb = roc_auc_score(testY, ridge_clf.predict(testX))
    ridgetest.append([alpha,aa,bb,aa+bb])
ridgetest
# Out:
# [[0.01, 1.0, 0.9959040036921657, 1.9959040036921656],
#  [0.1, 1.0, 0.99750490365755162, 1.9975049036575516],
#  [1, 1.0, 0.99854332525672096, 1.9985433252567208],
#  [10, 1.0, 0.99920676127841235, 1.9992067612784123],
#  [100, 0.99901317394706923, 0.9989760009230414, 1.9979891748701106],
#  [1000, 0.99203851874879123, 0.99663955232491064, 1.9886780710737018]]

# %%
words_avg=[]
for i in range(len(messages)):
    words = messages[i].split()
    average = sum(len(word) for word in words)/float(len(words))
    words_avg.append([average])
#words_avg_arr=numpy.asarray(words_avg)
combined2 = numpy.hstack((combined, words_avg))

# %%
words_avg=[]
for i in range(len(kaggle_test_messages)):
    words = messages[i].split()
    average = sum(len(word) for word in words)/float(len(words))
    words_avg.append([average])
#words_avg_arr=numpy.asarray(words_avg)
#combined2 = numpy.hstack((test_counts, words_avg))

# %%
combined_test = numpy.hstack((test_counts,kaggle_test_features,words_avg))

# %%
trainX, testX, trainY, testY = train_test_split(combined2, answers, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
nb_test = []
for alpha in numpy.arange(0.001, 0.01, 0.001):
    nb_clf = MultinomialNB(alpha)
    nb_clf.fit(trainX, trainY)
    aa = roc_auc_score(trainY, nb_clf.predict_proba(trainX)[:,1])
    bb = roc_auc_score(testY, nb_clf.predict_proba(testX)[:,1])
    nb_test.append([alpha,aa,bb,aa+bb])
nb_test
# Out:
# [[0.001, 0.99784109208749849, 0.98329871928002766, 1.9811398113675263],
#  [0.002, 0.99772903491665288, 0.98324102919118506, 1.9809700641078378],
#  [0.0030000000000000001,
#   0.99765945102830533,
#   0.98270018460828434,
#   1.9803596356365896],
#  [0.0040000000000000001,
#   0.9975952892611275,
#   0.98252711434175621,
#   1.9801224036028837],
#  [0.0050000000000000001,
#   0.99754468279687469,
#   0.98226029768085843,
#   1.9798049804777331],
#  [0.0060000000000000001,
#   0.99748865421145183,
#   0.9825703819083883,
#   1.9800590361198402],
#  [0.0070000000000000001,
#   0.99744798830267722,
#   0.98227472020306916,
#   1.9797227085057463],
#  [0.0080000000000000002,
#   0.99740370764645603,
#   0.98249105803622938,
#   1.9798947656826855],
#  [0.0090000000000000011,
#   0.99736213805081964,
#   0.98608226606668969,
#   1.9834444041175092]]

# %% [markdown]
# ** Exercise #4.** Print examples on which your classifier makes mistakes (both false positive and false negative).
#
# This is important step to understand what can be done to improve the classifier

# %%
#prediction results
pred = ridge_clf.predict(testX)

#change it to binary results
pred_bin = (pred>0.5)

# %%
## Confusion matrix
from sklearn import metrics
# testing score
metrics.confusion_matrix(testY, pred_bin)
# Out:
# array([[642,   0],
#        [ 13,  95]])

# %%
(pred<0).sum()
# Out:
# 231

# %% [markdown]
# ## results show that large number of false positive. What should be used to get a score that considers false positive?

# %% [markdown]
# ** Exercise #5. (optional, just for fun)**  write a spam SMS, which is not caught by your best model.
# Something like "Send sms YES to 091231323 to activate amazing spam filter, FREE for two weeks, then 20p/day. Txt now!".
#
# Use your knowledge about the structure of the model.

# %% [markdown]
# ** Major Goal (not in the homework). ** Provide best classification model for the problem.
#
# You can start with computing new features:
# 1. Computing occurences of symbols
# 2. Ignoring the words with digits, dots, etc.
# 3. Detect links, phones in text
#
# Or start with changing parameters of classifiers.
